# %%
import argparse
import os
import random,numpy
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import torchvision.transforms.functional as RF
from PIL import Image
import numpy as np
import random,cv2,pandas,os,numpy
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
seed = 999
print("Random Seed: ", seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

workers = 2
nz = 100
beta1 = 0.5
lr = 0.0001
ngpu=1
ngf,nc = 3,3
ndf = 64

device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
# Out:
# Random Seed:  999

# %%
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight.data, gain=0.02)
        
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.rafire=nn.Sequential(

            nn.Linear(12416, 2024),
            nn.Dropout(p=0.35),
            nn.SiLU(),
            
            nn.Linear(2024, 1524),
            nn.Dropout(p=0.35),
            nn.SiLU(),
            
            nn.Linear(1524, 1124),
            nn.Dropout(p=0.30),
            nn.SiLU(),
            
            nn.Linear(1124, 924),
            nn.Dropout(p=0.30),
            nn.SiLU(),
            
            nn.Linear(924, 824),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(824, 724),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(724, 624),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(624, 524),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(524, 424),
            nn.Dropout(p=0.15),
            nn.SiLU(),
            
            nn.Linear(424, 324),
            nn.Dropout(p=0.1),
            nn.SiLU(),
            
            nn.Linear(324, 283),
            nn.SiLU()
        )

    def forward(self,x):
        return self.rafire(x)

# %%
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight.data, gain=0.02)
        
class Discriminator_z(nn.Module):
    def __init__(self):
        super().__init__()
        self.rafire=nn.Sequential(

            nn.Linear(283, 924),
            nn.Dropout(p=0.30),
            nn.SiLU(),
            
            nn.Linear(924, 824),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(824, 724),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(724, 624),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(624, 524),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(524, 424),
            nn.Dropout(p=0.15),
            nn.SiLU(),
            
            nn.Linear(424, 324),
            nn.Dropout(p=0.1),
            nn.SiLU(),
            
            nn.Linear(324, 283),
            nn.SiLU()
        )

    def forward(self,x):
        return self.rafire(x)

# %%
netD = Discriminator().to(device)
if (device.type == 'cuda') and (ngpu > 1):
    netD = nn.DataParallel(netD, list(range(ngpu)))
netD.apply(weights_init)

netD.load_state_dict(torch.load(f"/kaggle/input/radire-model/result_rf_wl/3.682476403810142e-07.pth",map_location=torch.device('cpu'),weights_only=False))

netZ = Discriminator_z().to(device)
if (device.type == 'cuda') and (ngpu > 1):
    netD = nn.DataParallel(netD, list(range(ngpu)))
netZ.apply(weights_init)
# Out:
# Discriminator_z(
#   (rafire): Sequential(
#     (0): Linear(in_features=283, out_features=924, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=924, out_features=824, bias=True)
#     (4): Dropout(p=0.25, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=824, out_features=724, bias=True)
#     (7): Dropout(p=0.25, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=724, out_features=624, bias=True)
#     (10): Dropout(p=0.2, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=624, out_features=524, bias=True)
#     (13): Dropout(p=0.2, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=524, out_features=424, bias=True)
#     (16): Dropout(p=0.15, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=424, out_features=324, bias=True)
#     (19): Dropout(p=0.1, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=324, out_features=283, bias=True)
#     (22): SiLU()
#   )
# )

# %%
criterion,img_devil = nn.MSELoss(),0
fixed_noise = torch.randn(1, nz, 1, 1, device=device)

optimizerZ = optim.AdamW(netD.parameters(), lr=lr,betas=(beta1, 0.999))
schedulerZ=torch.optim.lr_scheduler.ExponentialLR(optimizerZ, gamma=0.86)

# %%
train_data=numpy.load(f"/kaggle/input/rafire-ariel/train_data.npy",allow_pickle='TRUE').item()
train_label_=pandas.read_csv("/kaggle/input/ariel-data-challenge-2024/train_labels.csv")
train_data_,train_label=[],[]

batch_size=10
batch_d,batch_l=[],[]
for i in train_data.keys():
    if len(batch_d)==batch_size:
        train_data_.append(numpy.array(batch_d)),train_label.append(numpy.array(batch_l))
        batch_d,batch_l=[],[]
    batch_d.append(train_data[i].reshape(-1))
    batch_l.append(numpy.array(train_label_[train_label_['planet_id']==int(i)]).reshape(-1)[1::])
    
train_data,train_label=torch.from_numpy(numpy.array(train_data_)).to(device),torch.from_numpy(numpy.array(train_label)).to(device)
train_data.shape,train_label.shape
# Out:
# (torch.Size([67, 10, 12416]), torch.Size([67, 10, 283]))

# %%
train_data_z=numpy.load(f"/kaggle/input/rafire-ariel/train_data.npy",allow_pickle='TRUE').item()

train_label_,z_w_=pandas.read_csv("/kaggle/input/ariel-data-challenge-2024/train_labels.csv"),[]
high_rf,i,j_r,k=1000,0,0,0
if os.path.exists(f"/kaggle/working/result_rf_sigma")==False:
    os.mkdir(f"/kaggle/working/result_rf_sigma")

while(True):
    optimizerZ.zero_grad()
    for data in range(len(train_data)):
        output = abs(netD(train_data[data].float())-0.0015)
        rafire_Z = abs(netZ(output.float()))
        errZ_real = criterion(rafire_Z.float(), (output.float()-train_label[data].float()))
        errZ_real.backward()
        optimizerZ.step()
    
    print(f"EPOCH:{i} LOSS_wl:{errZ_real.item()}")
    if len(z_w_)>=3:
        if len([True for i in range(1,4) if z_w_[len(z_w_)-i]<=z_w_[len(z_w_)-3] and z_w_[len(z_w_)-i]>=z_w_[len(z_w_)-4]])==3:
            z_w_,j_r=[],0
            print(f"lr_br:{optimizerZ.param_groups[0]['lr']}".upper())
            schedulerZ.step()
            print(f"lr_up:{optimizerZ.param_groups[0]['lr']}".upper())
    z_w_.append(errZ_real.item())
    
    if k==10:
        k=0
        if errZ_real.item()<high_rf:
            high_rf=errZ_real.item()
            torch.save(netZ.state_dict(),f'/kaggle/working/result_rf_sigma/{errZ_real.item()}.pth')
        for i_ in train_label_['planet_id'][:2]:
            real_cpu=torch.from_numpy(train_data_z[i_].reshape(-1)).to(device)
            output = abs(netD(real_cpu.float())-0.0015)
            rafire_Z = abs(netZ(output.float()))           
            print(f"PREDICTED: {rafire_Z[:5].cpu().detach().numpy()}")
            label=numpy.array(train_label_[train_label_['planet_id']==int(i_)]).reshape(-1)[1::]
            print(f"TRUE: {label[:5]-output[:5].cpu().detach().numpy()}")

        for i_ in train_label_['planet_id'][:2]:
            label=numpy.array(train_label_[train_label_['planet_id']==int(i_)]).reshape(-1)[1::]
            print(f"TRUE: {label[:5]}")

    if i>=1000:
        break
    i+=1
    j_r+=1
    k+=1
# Out:
# EPOCH:0 LOSS_wl:0.08283992856740952
# EPOCH:1 LOSS_wl:2.4037946786847897e-05
# EPOCH:2 LOSS_wl:3.690741868922487e-05
# EPOCH:3 LOSS_wl:2.819763722072821e-06
# EPOCH:4 LOSS_wl:2.678754526641569e-06
# EPOCH:5 LOSS_wl:3.449680662015453e-06
# EPOCH:6 LOSS_wl:3.0609662644565105e-06
# EPOCH:7 LOSS_wl:2.5785770958464127e-06
# EPOCH:8 LOSS_wl:3.0085802791290917e-06
# EPOCH:9 LOSS_wl:3.1371109798783436e-06
# EPOCH:10 LOSS_wl:2.8930301141372183e-06
# PREDICTED: [0.01905171 0.00617565 0.01164688 0.01372032 0.0129131 ]
# TRUE: [-0.02018386 -0.00817046 -0.01320222 -0.016138   -0.01425376]
# PREDICTED: [0.01908698 0.00634297 0.01163803 0.0137192  0.01283691]
# TRUE: [-0.01987758 -0.00796829 -0.01304875 -0.01536185 -0.0140047 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:11 LOSS_wl:2.6037712359539e-06
# EPOCH:12 LOSS_wl:2.4010275865293806e-06
# EPOCH:13 LOSS_wl:2.2119561435829382e-06
# EPOCH:14 LOSS_wl:2.1243145056359936e-06
# EPOCH:15 LOSS_wl:2.5489216568530537e-06
# EPOCH:16 LOSS_wl:2.7794255856861128e-06
# EPOCH:17 LOSS_wl:3.1593813218933064e-06
# EPOCH:18 LOSS_wl:3.435949565755436e-06
# EPOCH:19 LOSS_wl:3.44041973221465e-06
# EPOCH:20 LOSS_wl:3.4115148537239293e-06
# PREDICTED: [0.01908144 0.00624245 0.01170376 0.01378023 0.01286938]
# TRUE: [-0.0206693  -0.00847235 -0.01390002 -0.01603909 -0.01485448]
# PREDICTED: [0.01909097 0.00629177 0.01162133 0.01372735 0.01281566]
# TRUE: [-0.01986183 -0.00787048 -0.01318764 -0.01529351 -0.01411577]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:21 LOSS_wl:2.845382823579712e-06
# EPOCH:22 LOSS_wl:2.894860244850861e-06
# EPOCH:23 LOSS_wl:2.029577672146843e-06
# EPOCH:24 LOSS_wl:1.923946456372505e-06
# EPOCH:25 LOSS_wl:1.6949049950198969e-06
# EPOCH:26 LOSS_wl:1.865919557531015e-06
# EPOCH:27 LOSS_wl:2.413687298030709e-06
# EPOCH:28 LOSS_wl:1.8857307395592215e-06
# EPOCH:29 LOSS_wl:2.3432539819623344e-06
# EPOCH:30 LOSS_wl:3.7314705423341366e-06
# LR_BR:0.0001
# LR_UP:8.6E-05
# PREDICTED: [0.01903748 0.00623579 0.01173862 0.01385067 0.01278944]
# TRUE: [-0.0198013  -0.00732805 -0.01255293 -0.01580745 -0.01375025]
# PREDICTED: [0.01906485 0.00622288 0.01174634 0.01376467 0.01282239]
# TRUE: [-0.01891518 -0.00650849 -0.01174092 -0.01504821 -0.0130047 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:31 LOSS_wl:2.0806919565075077e-06
# EPOCH:32 LOSS_wl:2.3829747988202143e-06
# EPOCH:33 LOSS_wl:1.904523060147767e-06
# EPOCH:34 LOSS_wl:1.6837933571878239e-06
# EPOCH:35 LOSS_wl:3.0658263767691096e-06
# EPOCH:36 LOSS_wl:1.7935489040610264e-06
# EPOCH:37 LOSS_wl:1.3712376585317543e-06
# EPOCH:38 LOSS_wl:1.5233540580084082e-06
# EPOCH:39 LOSS_wl:1.6042064316934557e-06
# EPOCH:40 LOSS_wl:1.918932412081631e-06
# PREDICTED: [0.01908633 0.00622187 0.01161615 0.01375564 0.01287421]
# TRUE: [-0.01984883 -0.00733779 -0.01263011 -0.01481931 -0.01390665]
# PREDICTED: [0.01915341 0.00621785 0.01163288 0.01374982 0.01282823]
# TRUE: [-0.01861385 -0.00619004 -0.01153482 -0.01367601 -0.01283269]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:41 LOSS_wl:1.5936419686113368e-06
# EPOCH:42 LOSS_wl:2.227725872216979e-06
# EPOCH:43 LOSS_wl:1.8471533849151456e-06
# EPOCH:44 LOSS_wl:1.9478345620882465e-06
# EPOCH:45 LOSS_wl:1.7019126516970573e-06
# LR_BR:8.6E-05
# LR_UP:7.396E-05
# EPOCH:46 LOSS_wl:1.3445217064145254e-06
# EPOCH:47 LOSS_wl:1.4265123127188417e-06
# EPOCH:48 LOSS_wl:1.6368560409318889e-06
# EPOCH:49 LOSS_wl:1.5200475900201127e-06
# EPOCH:50 LOSS_wl:1.2749691222779802e-06
# PREDICTED: [0.01913156 0.00629939 0.0116536  0.01377261 0.01287425]
# TRUE: [-0.02000602 -0.00731678 -0.01254317 -0.01487984 -0.01369741]
# PREDICTED: [0.01902193 0.00623453 0.01170525 0.01376188 0.01283575]
# TRUE: [-0.01953974 -0.0067949  -0.0121992  -0.01453619 -0.01334669]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:51 LOSS_wl:8.798282919997291e-07
# EPOCH:52 LOSS_wl:7.102540280357061e-07
# EPOCH:53 LOSS_wl:7.570153570668481e-07
# EPOCH:54 LOSS_wl:1.11038002614805e-06
# EPOCH:55 LOSS_wl:1.1990382517979015e-06
# EPOCH:56 LOSS_wl:9.501749786977598e-07
# EPOCH:57 LOSS_wl:1.2076327493559802e-06
# EPOCH:58 LOSS_wl:1.0960527561110212e-06
# EPOCH:59 LOSS_wl:1.1899876426468836e-06
# EPOCH:60 LOSS_wl:1.4432222315008403e-06
# LR_BR:7.396E-05
# LR_UP:6.36056E-05
# PREDICTED: [0.01904137 0.00625031 0.01161027 0.01372136 0.01279823]
# TRUE: [-0.02007274 -0.00724267 -0.01255322 -0.01476551 -0.01373767]
# PREDICTED: [0.01905332 0.00637759 0.01161884 0.01374795 0.01278794]
# TRUE: [-0.01936247 -0.00644378 -0.01181703 -0.01394033 -0.01307262]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:61 LOSS_wl:1.5474913652724354e-06
# EPOCH:62 LOSS_wl:1.2381404985717381e-06
# EPOCH:63 LOSS_wl:1.066209961209097e-06
# EPOCH:64 LOSS_wl:1.2200041510368465e-06
# EPOCH:65 LOSS_wl:8.48717036205926e-07
# EPOCH:66 LOSS_wl:1.0432212320665712e-06
# EPOCH:67 LOSS_wl:1.1360082226019586e-06
# EPOCH:68 LOSS_wl:1.1060933502449188e-06
# EPOCH:69 LOSS_wl:1.0542486279518926e-06
# EPOCH:70 LOSS_wl:1.2579940857904148e-06
# LR_BR:6.36056E-05
# LR_UP:5.4700816E-05
# PREDICTED: [0.01918434 0.00633139 0.01169846 0.01384736 0.01281452]
# TRUE: [-0.01969875 -0.00679549 -0.01209969 -0.01452554 -0.01328204]
# PREDICTED: [0.019043   0.00633188 0.01164321 0.01373325 0.01282339]
# TRUE: [-0.01907605 -0.00620994 -0.0115576  -0.01392657 -0.01275526]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:71 LOSS_wl:6.299645178842184e-07
# EPOCH:72 LOSS_wl:9.239681730832672e-07
# EPOCH:73 LOSS_wl:7.044072276585212e-07
# EPOCH:74 LOSS_wl:1.0352575827710098e-06
# EPOCH:75 LOSS_wl:6.653062314398994e-07
# EPOCH:76 LOSS_wl:9.12718974177551e-07
# EPOCH:77 LOSS_wl:7.291990868907305e-07
# EPOCH:78 LOSS_wl:1.0451021807966754e-06
# EPOCH:79 LOSS_wl:9.080069958145032e-07
# EPOCH:80 LOSS_wl:9.37635547870741e-07
# PREDICTED: [0.0190324  0.00630506 0.01169839 0.01376564 0.01279582]
# TRUE: [-0.01952366 -0.00687142 -0.01215957 -0.01429576 -0.01333991]
# PREDICTED: [0.01902759 0.00628249 0.01159959 0.01375386 0.01282796]
# TRUE: [-0.01942054 -0.00678424 -0.01209239 -0.01416282 -0.01322963]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:81 LOSS_wl:1.020153490571829e-06
# LR_BR:5.4700816E-05
# LR_UP:4.704270176E-05
# EPOCH:82 LOSS_wl:1.0280259630235378e-06
# EPOCH:83 LOSS_wl:9.052918130691978e-07
# EPOCH:84 LOSS_wl:8.312249519804027e-07
# EPOCH:85 LOSS_wl:7.831397397239925e-07
# EPOCH:86 LOSS_wl:8.62012711877469e-07
# EPOCH:87 LOSS_wl:7.380398869827332e-07
# EPOCH:88 LOSS_wl:6.595411718990363e-07
# EPOCH:89 LOSS_wl:8.46672662646597e-07
# EPOCH:90 LOSS_wl:8.602914363109448e-07
# PREDICTED: [0.01908201 0.00628459 0.01166979 0.01384783 0.01278851]
# TRUE: [-0.01941491 -0.00668953 -0.01195539 -0.01399309 -0.01315223]
# PREDICTED: [0.0190313  0.00630803 0.01170775 0.01373762 0.01293585]
# TRUE: [-0.01835005 -0.00558932 -0.01089525 -0.01291967 -0.01211726]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:91 LOSS_wl:7.072341645653069e-07
# EPOCH:92 LOSS_wl:5.569197583099594e-07
# EPOCH:93 LOSS_wl:7.331110509767313e-07
# EPOCH:94 LOSS_wl:9.174728461402992e-07
# EPOCH:95 LOSS_wl:7.611383239236602e-07
# EPOCH:96 LOSS_wl:6.206154239407624e-07
# EPOCH:97 LOSS_wl:7.644150628038915e-07
# EPOCH:98 LOSS_wl:6.210716492205393e-07
# EPOCH:99 LOSS_wl:8.030253866309067e-07
# EPOCH:100 LOSS_wl:7.595373858748644e-07
# PREDICTED: [0.01905693 0.00626085 0.01161689 0.01368837 0.01285736]
# TRUE: [-0.01901826 -0.00616804 -0.01150937 -0.01355608 -0.01280374]
# PREDICTED: [0.01903064 0.00626783 0.01163873 0.01379046 0.01284627]
# TRUE: [-0.01853215 -0.00562556 -0.01102323 -0.0129913  -0.01231462]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:101 LOSS_wl:8.385116530007508e-07
# EPOCH:102 LOSS_wl:8.302454830300121e-07
# EPOCH:103 LOSS_wl:1.0680421382858185e-06
# EPOCH:104 LOSS_wl:1.7024382259478443e-06
# EPOCH:105 LOSS_wl:2.3776690341037465e-06
# EPOCH:106 LOSS_wl:1.4342248277898761e-06
# EPOCH:107 LOSS_wl:8.441425052296836e-07
# EPOCH:108 LOSS_wl:1.1313277354929596e-06
# EPOCH:109 LOSS_wl:1.4272869748310768e-06
# EPOCH:110 LOSS_wl:1.7110494354710681e-06
# PREDICTED: [0.01921152 0.00624155 0.01164178 0.01384026 0.01286957]
# TRUE: [-0.01949039 -0.00630311 -0.01176733 -0.01371257 -0.01303467]
# PREDICTED: [0.01906459 0.00626874 0.01155379 0.01381597 0.01281468]
# TRUE: [-0.01899603 -0.00586781 -0.01144603 -0.01334413 -0.01262612]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:111 LOSS_wl:8.064230883064738e-07
# EPOCH:112 LOSS_wl:1.1419633665354922e-06
# EPOCH:113 LOSS_wl:1.200480028273887e-06
# EPOCH:114 LOSS_wl:1.1617064501479035e-06
# EPOCH:115 LOSS_wl:6.260045211092802e-07
# EPOCH:116 LOSS_wl:7.521382485720096e-07
# EPOCH:117 LOSS_wl:6.297696018009447e-07
# EPOCH:118 LOSS_wl:6.633150633206242e-07
# EPOCH:119 LOSS_wl:6.44846068098559e-07
# LR_BR:4.704270176E-05
# LR_UP:4.04567235136E-05
# EPOCH:120 LOSS_wl:5.580517381531536e-07
# PREDICTED: [0.01903959 0.00617175 0.01163623 0.01371721 0.01282761]
# TRUE: [-0.0194203  -0.00665409 -0.01196585 -0.01430615 -0.01315923]
# PREDICTED: [0.01906823 0.00627524 0.01164416 0.01372822 0.01283962]
# TRUE: [-0.01898955 -0.00628197 -0.01159139 -0.0138684  -0.01281199]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:121 LOSS_wl:6.778276429031393e-07
# EPOCH:122 LOSS_wl:7.280255545083492e-07
# EPOCH:123 LOSS_wl:5.840794869982346e-07
# EPOCH:124 LOSS_wl:6.012198241478472e-07
# EPOCH:125 LOSS_wl:5.358514272302273e-07
# EPOCH:126 LOSS_wl:5.750310947405524e-07
# EPOCH:127 LOSS_wl:9.924576716002775e-07
# EPOCH:128 LOSS_wl:6.849894589322503e-07
# EPOCH:129 LOSS_wl:8.775455739851168e-07
# EPOCH:130 LOSS_wl:7.629731726410682e-07
# LR_BR:4.04567235136E-05
# LR_UP:3.4792782221696E-05
# PREDICTED: [0.01905225 0.00622342 0.01167748 0.01379003 0.01288009]
# TRUE: [-0.01923706 -0.00645679 -0.01176269 -0.01404707 -0.01295738]
# PREDICTED: [0.01907792 0.00624234 0.01167139 0.01374205 0.01289679]
# TRUE: [-0.01898304 -0.00625408 -0.01157791 -0.01380745 -0.01277132]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:131 LOSS_wl:7.599281275361136e-07
# EPOCH:132 LOSS_wl:8.90104047357454e-07
# EPOCH:133 LOSS_wl:6.48555840143672e-07
# EPOCH:134 LOSS_wl:6.850793283774692e-07
# EPOCH:135 LOSS_wl:6.931341545168834e-07
# EPOCH:136 LOSS_wl:7.242372248583706e-07
# EPOCH:137 LOSS_wl:7.158908488236193e-07
# EPOCH:138 LOSS_wl:9.104609830501431e-07
# EPOCH:139 LOSS_wl:7.780581086080929e-07
# EPOCH:140 LOSS_wl:9.335512913821731e-07
# PREDICTED: [0.01912579 0.00632732 0.01175544 0.01374763 0.01289159]
# TRUE: [-0.01981312 -0.0070963  -0.01231341 -0.01432302 -0.01351906]
# PREDICTED: [0.01913697 0.00631403 0.01159359 0.01381258 0.01291005]
# TRUE: [-0.01925362 -0.00663169 -0.01178259 -0.0138078  -0.01302671]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:141 LOSS_wl:5.198505732550984e-07
# EPOCH:142 LOSS_wl:7.321487487388367e-07
# EPOCH:143 LOSS_wl:5.322606853042089e-07
# EPOCH:144 LOSS_wl:5.973590191388212e-07
# EPOCH:145 LOSS_wl:5.16749480539147e-07
# LR_BR:3.4792782221696E-05
# LR_UP:2.992179271065856E-05
# EPOCH:146 LOSS_wl:5.483062182065623e-07
# EPOCH:147 LOSS_wl:4.80854794204788e-07
# EPOCH:148 LOSS_wl:4.2685962853283854e-07
# EPOCH:149 LOSS_wl:5.545994667954801e-07
# EPOCH:150 LOSS_wl:4.744325678984751e-07
# PREDICTED: [0.01912549 0.00629844 0.01169922 0.0137999  0.01291249]
# TRUE: [-0.01900843 -0.00627374 -0.01144096 -0.01365838 -0.01267224]
# PREDICTED: [0.01912692 0.00620571 0.01160333 0.01377468 0.01280169]
# TRUE: [-0.01853553 -0.005826   -0.01102924 -0.01316617 -0.012279  ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:151 LOSS_wl:5.544902705878485e-07
# EPOCH:152 LOSS_wl:4.3450228304209304e-07
# LR_BR:2.992179271065856E-05
# LR_UP:2.573274173116636E-05
# EPOCH:153 LOSS_wl:5.086115493213583e-07
# EPOCH:154 LOSS_wl:5.471791268973902e-07
# EPOCH:155 LOSS_wl:5.381893402045534e-07
# EPOCH:156 LOSS_wl:4.822423420591804e-07
# EPOCH:157 LOSS_wl:4.50294209031199e-07
# EPOCH:158 LOSS_wl:5.189918965697871e-07
# EPOCH:159 LOSS_wl:5.007844947613194e-07
# EPOCH:160 LOSS_wl:5.703440137949656e-07
# PREDICTED: [0.01908149 0.00631634 0.01173838 0.01377194 0.01282074]
# TRUE: [-0.01884076 -0.00594577 -0.01129862 -0.01359361 -0.01247613]
# PREDICTED: [0.01910378 0.00636392 0.01167213 0.01370334 0.01289312]
# TRUE: [-0.01846018 -0.00562375 -0.01096322 -0.01322291 -0.01213163]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:161 LOSS_wl:5.586655902334314e-07
# EPOCH:162 LOSS_wl:6.851619787084928e-07
# EPOCH:163 LOSS_wl:6.412737434402516e-07
# EPOCH:164 LOSS_wl:5.126299811308854e-07
# EPOCH:165 LOSS_wl:5.29407259364234e-07
# EPOCH:166 LOSS_wl:5.940341338828148e-07
# EPOCH:167 LOSS_wl:5.13495933773811e-07
# EPOCH:168 LOSS_wl:1.0005770718635176e-06
# EPOCH:169 LOSS_wl:8.063528298407618e-07
# EPOCH:170 LOSS_wl:6.225238280421763e-07
# PREDICTED: [0.01912287 0.00626132 0.01162773 0.01373373 0.01285078]
# TRUE: [-0.01971343 -0.00688828 -0.0122911  -0.01439337 -0.01344121]
# PREDICTED: [0.01907727 0.0062618  0.01172197 0.01385161 0.01284099]
# TRUE: [-0.01863892 -0.00591633 -0.01134546 -0.01336572 -0.01249603]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:171 LOSS_wl:9.343142437501228e-07
# LR_BR:2.573274173116636E-05
# LR_UP:2.213015788880307E-05
# EPOCH:172 LOSS_wl:1.437350192645681e-06
# EPOCH:173 LOSS_wl:4.7526606294923113e-07
# EPOCH:174 LOSS_wl:5.121250410411449e-07
# EPOCH:175 LOSS_wl:4.2067304661941307e-07
# EPOCH:176 LOSS_wl:4.3340762090338103e-07
# EPOCH:177 LOSS_wl:5.406888590187009e-07
# EPOCH:178 LOSS_wl:5.131642524247582e-07
# EPOCH:179 LOSS_wl:4.439016834112408e-07
# EPOCH:180 LOSS_wl:4.171239140760008e-07
# LR_BR:2.213015788880307E-05
# LR_UP:1.9031935784370638E-05
# PREDICTED: [0.01902501 0.00625946 0.01162334 0.01382108 0.01284054]
# TRUE: [-0.01924729 -0.00635489 -0.01172928 -0.0137882  -0.01293067]
# PREDICTED: [0.01910947 0.00616198 0.01173365 0.01374965 0.01283071]
# TRUE: [-0.01851448 -0.00567831 -0.01110549 -0.01314004 -0.01227667]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:181 LOSS_wl:4.78055767416663e-07
# EPOCH:182 LOSS_wl:3.9076743973964767e-07
# EPOCH:183 LOSS_wl:5.357234726943716e-07
# EPOCH:184 LOSS_wl:4.2486178131184715e-07
# EPOCH:185 LOSS_wl:5.760578574154351e-07
# EPOCH:186 LOSS_wl:4.1556310748092073e-07
# EPOCH:187 LOSS_wl:6.434892725337704e-07
# EPOCH:188 LOSS_wl:4.551975507638417e-07
# EPOCH:189 LOSS_wl:5.977040586913063e-07
# EPOCH:190 LOSS_wl:4.152649637489958e-07
# LR_BR:1.9031935784370638E-05
# LR_UP:1.636746477455875E-05
# PREDICTED: [0.01917605 0.00628639 0.01155444 0.01383554 0.01284947]
# TRUE: [-0.01958013 -0.00664072 -0.0120122  -0.01415804 -0.01323819]
# PREDICTED: [0.01908392 0.0063041  0.01164798 0.01369394 0.01283389]
# TRUE: [-0.01863678 -0.00572902 -0.01110812 -0.01324654 -0.01232925]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:191 LOSS_wl:6.802394523219846e-07
# EPOCH:192 LOSS_wl:3.946503284169012e-07
# EPOCH:193 LOSS_wl:8.402788580497145e-07
# EPOCH:194 LOSS_wl:4.2255271637259284e-07
# EPOCH:195 LOSS_wl:8.348191045115527e-07
# EPOCH:196 LOSS_wl:6.860857411083998e-07
# LR_BR:1.636746477455875E-05
# LR_UP:1.4076019706120523E-05
# EPOCH:197 LOSS_wl:1.1392814940336393e-06
# EPOCH:198 LOSS_wl:4.070805914579978e-07
# EPOCH:199 LOSS_wl:6.107958938628144e-07
# EPOCH:200 LOSS_wl:4.296221902677644e-07
# PREDICTED: [0.01908292 0.00618728 0.01168637 0.01381638 0.0128059 ]
# TRUE: [-0.01940023 -0.00656893 -0.01199574 -0.01413329 -0.01315935]
# PREDICTED: [0.01912812 0.00629488 0.01162299 0.01376153 0.01279784]
# TRUE: [-0.01848621 -0.00572962 -0.01110381 -0.01324405 -0.01231437]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:201 LOSS_wl:6.638125000790751e-07
# EPOCH:202 LOSS_wl:6.231039151316509e-07
# EPOCH:203 LOSS_wl:1.0382187838331447e-06
# EPOCH:204 LOSS_wl:3.8449024941655807e-07
# EPOCH:205 LOSS_wl:5.058062697571586e-07
# EPOCH:206 LOSS_wl:4.836937250729534e-07
# EPOCH:207 LOSS_wl:4.3403019844845403e-07
# EPOCH:208 LOSS_wl:4.6498169581354887e-07
# LR_BR:1.4076019706120523E-05
# LR_UP:1.210537694726365E-05
# EPOCH:209 LOSS_wl:7.909324040156207e-07
# EPOCH:210 LOSS_wl:6.291008958214661e-07
# PREDICTED: [0.01911131 0.00626579 0.01165852 0.01376683 0.01282802]
# TRUE: [-0.01977942 -0.00689973 -0.01227264 -0.01445127 -0.01345115]
# PREDICTED: [0.01908015 0.00627543 0.01159189 0.01380802 0.01274416]
# TRUE: [-0.01917239 -0.00637576 -0.01172266 -0.01386179 -0.01292256]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:211 LOSS_wl:5.478668754221871e-07
# EPOCH:212 LOSS_wl:5.358779731068353e-07
# LR_BR:1.210537694726365E-05
# LR_UP:1.0410624174646739E-05
# EPOCH:213 LOSS_wl:4.345270383510069e-07
# EPOCH:214 LOSS_wl:4.920864853374951e-07
# EPOCH:215 LOSS_wl:4.950167067363509e-07
# EPOCH:216 LOSS_wl:4.682973724356998e-07
# EPOCH:217 LOSS_wl:4.6450344370896346e-07
# EPOCH:218 LOSS_wl:4.496833412304113e-07
# EPOCH:219 LOSS_wl:5.167256631466444e-07
# EPOCH:220 LOSS_wl:4.85416421724949e-07
# PREDICTED: [0.01910781 0.00624376 0.01171609 0.0137802  0.01290789]
# TRUE: [-0.01939283 -0.00638852 -0.01174806 -0.01400799 -0.01296879]
# PREDICTED: [0.0190948  0.00628922 0.01166178 0.01372147 0.01281855]
# TRUE: [-0.01847601 -0.00555656 -0.01087016 -0.01314656 -0.01209487]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:221 LOSS_wl:4.34313619734894e-07
# EPOCH:222 LOSS_wl:4.2037521552629187e-07
# EPOCH:223 LOSS_wl:4.860851845478464e-07
# EPOCH:224 LOSS_wl:6.029908945492934e-07
# EPOCH:225 LOSS_wl:5.349292564460484e-07
# EPOCH:226 LOSS_wl:4.952829044668761e-07
# EPOCH:227 LOSS_wl:4.873791681347939e-07
# LR_BR:1.0410624174646739E-05
# LR_UP:8.953136790196195E-06
# EPOCH:228 LOSS_wl:4.92604783630668e-07
# EPOCH:229 LOSS_wl:4.213472664105211e-07
# EPOCH:230 LOSS_wl:4.4218671746421023e-07
# PREDICTED: [0.01910966 0.00625971 0.0116448  0.01377674 0.01275903]
# TRUE: [-0.01974205 -0.00652602 -0.01187338 -0.0143423  -0.01303192]
# PREDICTED: [0.0190637  0.00629001 0.01150614 0.01381878 0.01286999]
# TRUE: [-0.01878528 -0.00559726 -0.01095342 -0.01341156 -0.0121183 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:231 LOSS_wl:5.58555484531098e-07
# EPOCH:232 LOSS_wl:5.584366249422601e-07
# EPOCH:233 LOSS_wl:4.778532343152619e-07
# EPOCH:234 LOSS_wl:5.492547074936738e-07
# LR_BR:8.953136790196195E-06
# LR_UP:7.699697639568727E-06
# EPOCH:235 LOSS_wl:5.177034267944691e-07
# EPOCH:236 LOSS_wl:4.547534047105728e-07
# EPOCH:237 LOSS_wl:5.406440664046386e-07
# LR_BR:7.699697639568727E-06
# LR_UP:6.621739970029105E-06
# EPOCH:238 LOSS_wl:5.029564817959908e-07
# EPOCH:239 LOSS_wl:4.4387479647411965e-07
# EPOCH:240 LOSS_wl:5.18893500611739e-07
# LR_BR:6.621739970029105E-06
# LR_UP:5.694696374225031E-06
# PREDICTED: [0.01909918 0.00628186 0.01169048 0.0137008  0.01282516]
# TRUE: [-0.01935642 -0.00627771 -0.01171903 -0.01398304 -0.0128951 ]
# PREDICTED: [0.01913296 0.00633249 0.01169945 0.01372358 0.01285949]
# TRUE: [-0.01842986 -0.00540323 -0.01083658 -0.01310518 -0.01201617]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:241 LOSS_wl:4.0267960343953746e-07
# EPOCH:242 LOSS_wl:5.038777999288868e-07
# EPOCH:243 LOSS_wl:4.7127849711614545e-07
# EPOCH:244 LOSS_wl:5.54684447706677e-07
# EPOCH:245 LOSS_wl:4.465180722945661e-07
# EPOCH:246 LOSS_wl:4.6296980826809886e-07
# EPOCH:247 LOSS_wl:4.51049913863244e-07
# EPOCH:248 LOSS_wl:5.105727041154751e-07
# EPOCH:249 LOSS_wl:5.041945314587792e-07
# EPOCH:250 LOSS_wl:4.7388144253091014e-07
# PREDICTED: [0.01906893 0.00629271 0.01175339 0.01376803 0.01282601]
# TRUE: [-0.01927913 -0.00642696 -0.01181396 -0.01394216 -0.01299629]
# PREDICTED: [0.01910709 0.00634376 0.0116232  0.0138039  0.01285796]
# TRUE: [-0.01840568 -0.00560224 -0.0109899  -0.0130914  -0.01219334]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:251 LOSS_wl:4.76369763191542e-07
# LR_BR:5.694696374225031E-06
# LR_UP:4.897438881833527E-06
# EPOCH:252 LOSS_wl:4.4518557729134045e-07
# EPOCH:253 LOSS_wl:4.1396012306904595e-07
# EPOCH:254 LOSS_wl:4.307569554384827e-07
# LR_BR:4.897438881833527E-06
# LR_UP:4.211797438376833E-06
# EPOCH:255 LOSS_wl:4.2732142446766375e-07
# EPOCH:256 LOSS_wl:5.268780682854413e-07
# EPOCH:257 LOSS_wl:4.3684349293471314e-07
# EPOCH:258 LOSS_wl:4.5379732682704343e-07
# EPOCH:259 LOSS_wl:4.777472213390865e-07
# LR_BR:4.211797438376833E-06
# LR_UP:3.622145797004077E-06
# EPOCH:260 LOSS_wl:4.4543224930748693e-07
# PREDICTED: [0.01906668 0.00630072 0.01161773 0.01382554 0.01287628]
# TRUE: [-0.01934863 -0.00648584 -0.01190215 -0.01396719 -0.01308934]
# PREDICTED: [0.0190303  0.00635599 0.01164194 0.01370979 0.01282915]
# TRUE: [-0.01841364 -0.00561434 -0.01101306 -0.01307076 -0.01220728]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:261 LOSS_wl:4.010543079857598e-07
# EPOCH:262 LOSS_wl:4.835756612919795e-07
# LR_BR:3.622145797004077E-06
# LR_UP:3.115045385423506E-06
# EPOCH:263 LOSS_wl:3.8507118915731553e-07
# EPOCH:264 LOSS_wl:4.725426947516098e-07
# EPOCH:265 LOSS_wl:4.7000361291793524e-07
# EPOCH:266 LOSS_wl:5.3213688033793e-07
# EPOCH:267 LOSS_wl:4.1581617438168905e-07
# EPOCH:268 LOSS_wl:4.929060537506302e-07
# EPOCH:269 LOSS_wl:5.033571142121218e-07
# EPOCH:270 LOSS_wl:4.787245302395604e-07
# PREDICTED: [0.0190606  0.00629171 0.01164347 0.01373153 0.01282879]
# TRUE: [-0.01932652 -0.00646078 -0.01184342 -0.01396049 -0.01304668]
# PREDICTED: [0.01906047 0.00635656 0.01165405 0.01376875 0.0128826 ]
# TRUE: [-0.01857049 -0.0057883  -0.01112168 -0.01326918 -0.01235654]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:271 LOSS_wl:5.171111752133584e-07
# EPOCH:272 LOSS_wl:4.189473372662178e-07
# EPOCH:273 LOSS_wl:4.0787233501760056e-07
# EPOCH:274 LOSS_wl:4.1360516433996963e-07
# EPOCH:275 LOSS_wl:5.215043756834348e-07
# EPOCH:276 LOSS_wl:4.846426691074157e-07
# EPOCH:277 LOSS_wl:4.870896077591169e-07
# EPOCH:278 LOSS_wl:4.379693336886703e-07
# LR_BR:3.115045385423506E-06
# LR_UP:2.6789390314642153E-06
# EPOCH:279 LOSS_wl:4.935569108965865e-07
# EPOCH:280 LOSS_wl:5.013400823372649e-07
# PREDICTED: [0.01902844 0.00620987 0.01169186 0.0137211  0.01292043]
# TRUE: [-0.01913459 -0.00625766 -0.01164322 -0.01379465 -0.01282051]
# PREDICTED: [0.0190892  0.00629147 0.01169046 0.01380862 0.0128242 ]
# TRUE: [-0.01849465 -0.00565923 -0.01104324 -0.01318417 -0.01223042]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:281 LOSS_wl:5.017768671677914e-07
# EPOCH:282 LOSS_wl:4.694944948369084e-07
# EPOCH:283 LOSS_wl:5.634333888338006e-07
# EPOCH:284 LOSS_wl:3.924179452496901e-07
# EPOCH:285 LOSS_wl:4.6573663325943926e-07
# EPOCH:286 LOSS_wl:4.708531946562289e-07
# EPOCH:287 LOSS_wl:4.911178166366881e-07
# EPOCH:288 LOSS_wl:4.2775104702741373e-07
# EPOCH:289 LOSS_wl:4.962827233612188e-07
# EPOCH:290 LOSS_wl:4.431702791407588e-07
# PREDICTED: [0.01912155 0.0062675  0.01161423 0.01387218 0.01287304]
# TRUE: [-0.0191598  -0.00630126 -0.01169277 -0.01381723 -0.01286936]
# PREDICTED: [0.01904151 0.00631505 0.01156795 0.01380707 0.01280052]
# TRUE: [-0.01811351 -0.00530008 -0.01068917 -0.01279192 -0.01189441]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:291 LOSS_wl:5.073383135822951e-07
# EPOCH:292 LOSS_wl:4.845345529247425e-07
# EPOCH:293 LOSS_wl:4.736216112632974e-07
# EPOCH:294 LOSS_wl:4.163755136232794e-07
# LR_BR:2.6789390314642153E-06
# LR_UP:2.303887567059225E-06
# EPOCH:295 LOSS_wl:4.6979084800113924e-07
# EPOCH:296 LOSS_wl:4.7269745095945837e-07
# EPOCH:297 LOSS_wl:4.406238645060512e-07
# EPOCH:298 LOSS_wl:4.5414134319798904e-07
# EPOCH:299 LOSS_wl:4.4079726535528607e-07
# EPOCH:300 LOSS_wl:4.5224248879094375e-07
# PREDICTED: [0.01905962 0.00624578 0.01164703 0.01377746 0.01274962]
# TRUE: [-0.01913723 -0.00632617 -0.01169627 -0.01381606 -0.01289457]
# PREDICTED: [0.01905719 0.00631942 0.01169592 0.01380711 0.01282373]
# TRUE: [-0.01828512 -0.00547608 -0.01087456 -0.01301928 -0.01205846]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:301 LOSS_wl:5.043646638114296e-07
# LR_BR:2.303887567059225E-06
# LR_UP:1.9813433076709336E-06
# EPOCH:302 LOSS_wl:3.6340063047646254e-07
# EPOCH:303 LOSS_wl:5.099790882923116e-07
# EPOCH:304 LOSS_wl:4.012804311059881e-07
# EPOCH:305 LOSS_wl:4.969542715116404e-07
# EPOCH:306 LOSS_wl:4.6934394504205557e-07
# LR_BR:1.9813433076709336E-06
# LR_UP:1.7039552445970028E-06
# EPOCH:307 LOSS_wl:4.832911599805811e-07
# EPOCH:308 LOSS_wl:5.223162702350237e-07
# EPOCH:309 LOSS_wl:3.9840523413658957e-07
# EPOCH:310 LOSS_wl:4.516530225373572e-07
# PREDICTED: [0.01905411 0.00629956 0.01164564 0.01373895 0.01288792]
# TRUE: [-0.01905749 -0.00622565 -0.01159682 -0.0137175  -0.01281084]
# PREDICTED: [0.01913496 0.00623599 0.01169829 0.01376261 0.01280526]
# TRUE: [-0.0183445  -0.00556265 -0.01093576 -0.01303775 -0.01213341]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:311 LOSS_wl:3.8575939242946333e-07
# EPOCH:312 LOSS_wl:4.929634087602608e-07
# EPOCH:313 LOSS_wl:4.522433982856455e-07
# EPOCH:314 LOSS_wl:5.148210107108753e-07
# EPOCH:315 LOSS_wl:4.212803048631031e-07
# EPOCH:316 LOSS_wl:4.930499812871858e-07
# EPOCH:317 LOSS_wl:4.6233196826506173e-07
# EPOCH:318 LOSS_wl:4.178857579972828e-07
# EPOCH:319 LOSS_wl:3.60977111313332e-07
# EPOCH:320 LOSS_wl:4.4778153096558526e-07
# PREDICTED: [0.01905262 0.00620885 0.01167911 0.01373938 0.01283956]
# TRUE: [-0.01904909 -0.00618936 -0.01158648 -0.01370029 -0.01275938]
# PREDICTED: [0.01909029 0.00629606 0.01163343 0.01372089 0.01285738]
# TRUE: [-0.0187248  -0.00593527 -0.01131496 -0.01342696 -0.01247776]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:321 LOSS_wl:4.233323238622688e-07
# EPOCH:322 LOSS_wl:4.2955878143402515e-07
# EPOCH:323 LOSS_wl:4.437886786945455e-07
# LR_BR:1.7039552445970028E-06
# LR_UP:1.4654015103534223E-06
# EPOCH:324 LOSS_wl:4.788387286680518e-07
# EPOCH:325 LOSS_wl:4.5979859919498267e-07
# EPOCH:326 LOSS_wl:5.151647997081454e-07
# EPOCH:327 LOSS_wl:4.485223144001793e-07
# EPOCH:328 LOSS_wl:4.997440328224911e-07
# EPOCH:329 LOSS_wl:4.664020423206239e-07
# EPOCH:330 LOSS_wl:4.585629937992053e-07
# PREDICTED: [0.01916237 0.00623224 0.01162063 0.013807   0.01280922]
# TRUE: [-0.0193028  -0.00644192 -0.01185917 -0.01395638 -0.01301512]
# PREDICTED: [0.01907017 0.00626449 0.01172636 0.01387063 0.01279615]
# TRUE: [-0.01858324 -0.00578159 -0.01116799 -0.01326258 -0.01235797]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:331 LOSS_wl:3.882236114804982e-07
# LR_BR:1.4654015103534223E-06
# LR_UP:1.2602452989039432E-06
# EPOCH:332 LOSS_wl:4.755000020395528e-07
# EPOCH:333 LOSS_wl:4.627240741683636e-07
# EPOCH:334 LOSS_wl:4.2622235696399e-07
# EPOCH:335 LOSS_wl:4.632919967662019e-07
# LR_BR:1.2602452989039432E-06
# LR_UP:1.083810957057391E-06
# EPOCH:336 LOSS_wl:3.869836007197591e-07
# EPOCH:337 LOSS_wl:4.313452564019826e-07
# EPOCH:338 LOSS_wl:4.3675910887941427e-07
# EPOCH:339 LOSS_wl:5.232855073700193e-07
# EPOCH:340 LOSS_wl:5.136423055773776e-07
# PREDICTED: [0.01906049 0.00631246 0.01173806 0.01374502 0.01285782]
# TRUE: [-0.01932579 -0.00647557 -0.01184529 -0.01395436 -0.01305353]
# PREDICTED: [0.01912042 0.00631732 0.01163659 0.01378776 0.01282318]
# TRUE: [-0.01832722 -0.00550986 -0.01090819 -0.01299638 -0.01209666]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:341 LOSS_wl:3.524334317717148e-07
# EPOCH:342 LOSS_wl:4.28887659609245e-07
# EPOCH:343 LOSS_wl:4.421714550062461e-07
# EPOCH:344 LOSS_wl:5.158558451512363e-07
# EPOCH:345 LOSS_wl:3.966030419633171e-07
# EPOCH:346 LOSS_wl:4.562806168451061e-07
# EPOCH:347 LOSS_wl:4.211569262224657e-07
# EPOCH:348 LOSS_wl:4.375966966563283e-07
# EPOCH:349 LOSS_wl:3.901609773038217e-07
# LR_BR:1.083810957057391E-06
# LR_UP:9.320774230693563E-07
# EPOCH:350 LOSS_wl:4.217666003114573e-07
# PREDICTED: [0.01908741 0.0062898  0.01178644 0.01377401 0.01287688]
# TRUE: [-0.01905925 -0.00622225 -0.01158964 -0.01370126 -0.01278115]
# PREDICTED: [0.01903395 0.00625239 0.01151841 0.01370407 0.01287339]
# TRUE: [-0.01858362 -0.0057954  -0.01116199 -0.01327227 -0.01237284]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:351 LOSS_wl:4.151182793066255e-07
# EPOCH:352 LOSS_wl:4.83481926494278e-07
# EPOCH:353 LOSS_wl:4.1283200857833435e-07
# EPOCH:354 LOSS_wl:4.1405564843444154e-07
# EPOCH:355 LOSS_wl:4.803038109457702e-07
# EPOCH:356 LOSS_wl:4.898981273981917e-07
# EPOCH:357 LOSS_wl:9.683668622528785e-07
# EPOCH:358 LOSS_wl:3.696805777053669e-07
# EPOCH:359 LOSS_wl:4.0997085193339444e-07
# EPOCH:360 LOSS_wl:4.556073633921187e-07
# PREDICTED: [0.01907498 0.00626971 0.01165487 0.01393248 0.01287112]
# TRUE: [-0.01942127 -0.00653942 -0.01192818 -0.01403979 -0.01310691]
# PREDICTED: [0.01905238 0.00630491 0.01168212 0.01368602 0.01285631]
# TRUE: [-0.01855427 -0.00578708 -0.01115755 -0.01326881 -0.01235456]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:361 LOSS_wl:3.9710687360638985e-07
# EPOCH:362 LOSS_wl:4.151227983584249e-07
# EPOCH:363 LOSS_wl:4.5316568275666214e-07
# EPOCH:364 LOSS_wl:4.3079251099698013e-07
# EPOCH:365 LOSS_wl:4.293987956316414e-07
# EPOCH:366 LOSS_wl:4.615215800640726e-07
# LR_BR:9.320774230693563E-07
# LR_UP:8.015865838396464E-07
# EPOCH:367 LOSS_wl:4.0067914142127847e-07
# EPOCH:368 LOSS_wl:4.648920821637148e-07
# EPOCH:369 LOSS_wl:4.2230388430652965e-07
# EPOCH:370 LOSS_wl:4.1205470324712223e-07
# PREDICTED: [0.01917019 0.00630757 0.01170533 0.01371813 0.01289211]
# TRUE: [-0.01921311 -0.00639482 -0.01178038 -0.01387088 -0.01296815]
# PREDICTED: [0.01914948 0.0062429  0.01169095 0.01377645 0.01287695]
# TRUE: [-0.01833488 -0.00550556 -0.01091623 -0.01301985 -0.01208926]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:371 LOSS_wl:4.347563447026914e-07
# LR_BR:8.015865838396464E-07
# LR_UP:6.893644621020959E-07
# EPOCH:372 LOSS_wl:4.458185856037744e-07
# EPOCH:373 LOSS_wl:4.419353274442983e-07
# EPOCH:374 LOSS_wl:4.779615778716106e-07
# EPOCH:375 LOSS_wl:5.219855552240915e-07
# EPOCH:376 LOSS_wl:4.126757744415954e-07
# EPOCH:377 LOSS_wl:3.9988324829209887e-07
# EPOCH:378 LOSS_wl:4.5924815594844404e-07
# EPOCH:379 LOSS_wl:4.611230508544395e-07
# EPOCH:380 LOSS_wl:3.925359237655357e-07
# PREDICTED: [0.01902643 0.00628341 0.01156046 0.01376651 0.01285038]
# TRUE: [-0.01915532 -0.00636498 -0.01170788 -0.01383276 -0.01289714]
# PREDICTED: [0.01900043 0.00631043 0.01158359 0.01372197 0.01285845]
# TRUE: [-0.01838277 -0.00556945 -0.0109563  -0.01305869 -0.01215711]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:381 LOSS_wl:4.497746601828112e-07
# EPOCH:382 LOSS_wl:4.5273463911144063e-07
# EPOCH:383 LOSS_wl:4.1799614791671047e-07
# EPOCH:384 LOSS_wl:5.001987233299587e-07
# EPOCH:385 LOSS_wl:4.332748630986316e-07
# EPOCH:386 LOSS_wl:4.289582022920513e-07
# EPOCH:387 LOSS_wl:3.6999043118157715e-07
# LR_BR:6.893644621020959E-07
# LR_UP:5.928534374078025E-07
# EPOCH:388 LOSS_wl:4.615844488853327e-07
# EPOCH:389 LOSS_wl:4.517222009781108e-07
# EPOCH:390 LOSS_wl:4.4961842604607227e-07
# PREDICTED: [0.01907448 0.00635531 0.01174699 0.01376675 0.0128177 ]
# TRUE: [-0.01932166 -0.00646635 -0.01187819 -0.01398386 -0.01304685]
# PREDICTED: [0.0191112  0.00628097 0.01172181 0.01369887 0.0128357 ]
# TRUE: [-0.01866571 -0.00589119 -0.01126106 -0.01336982 -0.01247271]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:391 LOSS_wl:4.839483835894498e-07
# LR_BR:5.928534374078025E-07
# LR_UP:5.098539561707101E-07
# EPOCH:392 LOSS_wl:4.1477500190012506e-07
# EPOCH:393 LOSS_wl:4.6710880496902973e-07
# EPOCH:394 LOSS_wl:4.5883004418101336e-07
# EPOCH:395 LOSS_wl:4.856079272030911e-07
# EPOCH:396 LOSS_wl:4.7376769884976966e-07
# EPOCH:397 LOSS_wl:4.5476656396203907e-07
# EPOCH:398 LOSS_wl:3.773899948100734e-07
# EPOCH:399 LOSS_wl:4.2326027482886275e-07
# EPOCH:400 LOSS_wl:4.381105895845394e-07
# PREDICTED: [0.01902949 0.0062292  0.01171568 0.01372866 0.01270455]
# TRUE: [-0.01902383 -0.00617191 -0.01159942 -0.01370706 -0.01277007]
# PREDICTED: [0.01910557 0.00620158 0.01161758 0.01382565 0.01276882]
# TRUE: [-0.01818009 -0.00539141 -0.01076286 -0.01285249 -0.01197042]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:401 LOSS_wl:4.1211418988496007e-07
# EPOCH:402 LOSS_wl:4.57779009366277e-07
# EPOCH:403 LOSS_wl:4.3734857513300085e-07
# EPOCH:404 LOSS_wl:4.537499194157135e-07
# EPOCH:405 LOSS_wl:4.1763408376027655e-07
# LR_BR:5.098539561707101E-07
# LR_UP:4.384744023068107E-07
# EPOCH:406 LOSS_wl:4.519635865563032e-07
# EPOCH:407 LOSS_wl:4.342908823673497e-07
# EPOCH:408 LOSS_wl:5.035369667893974e-07
# EPOCH:409 LOSS_wl:3.5025115607822954e-07
# EPOCH:410 LOSS_wl:4.604142702646641e-07
# PREDICTED: [0.01913132 0.00630902 0.01164638 0.01380248 0.0129363 ]
# TRUE: [-0.01939544 -0.00658586 -0.01197419 -0.01406696 -0.01316883]
# PREDICTED: [0.0190881  0.00625974 0.01164249 0.01380002 0.01282747]
# TRUE: [-0.01850703 -0.00570601 -0.01109177 -0.0132273  -0.01226777]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:411 LOSS_wl:3.9747189362060453e-07
# EPOCH:412 LOSS_wl:4.3617745859592105e-07
# EPOCH:413 LOSS_wl:4.253205361237633e-07
# LR_BR:4.384744023068107E-07
# LR_UP:3.770879859838572E-07
# EPOCH:414 LOSS_wl:4.5691763261856977e-07
# EPOCH:415 LOSS_wl:4.873053285336937e-07
# EPOCH:416 LOSS_wl:4.6970916400823626e-07
# EPOCH:417 LOSS_wl:4.771849830831343e-07
# EPOCH:418 LOSS_wl:4.6803836539766053e-07
# LR_BR:3.770879859838572E-07
# LR_UP:3.242956679461172E-07
# EPOCH:419 LOSS_wl:4.538676137144648e-07
# EPOCH:420 LOSS_wl:4.7039745254551235e-07
# PREDICTED: [0.01898564 0.00627672 0.01163553 0.01372748 0.01288077]
# TRUE: [-0.01921045 -0.00639218 -0.01175458 -0.01385222 -0.0129665 ]
# PREDICTED: [0.0191406  0.00625928 0.01162604 0.0137187  0.01277172]
# TRUE: [-0.01846902 -0.00568462 -0.01107082 -0.01317094 -0.01225464]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:421 LOSS_wl:4.4415727984414843e-07
# EPOCH:422 LOSS_wl:4.663436357077444e-07
# EPOCH:423 LOSS_wl:4.211098030282301e-07
# EPOCH:424 LOSS_wl:4.2220770524181717e-07
# EPOCH:425 LOSS_wl:5.310326969265589e-07
# EPOCH:426 LOSS_wl:4.822658752345887e-07
# EPOCH:427 LOSS_wl:4.0044926663540537e-07
# EPOCH:428 LOSS_wl:4.4383583031049056e-07
# EPOCH:429 LOSS_wl:4.568329643461766e-07
# EPOCH:430 LOSS_wl:4.2446711745469656e-07
# PREDICTED: [0.01907428 0.00628085 0.01157404 0.01382926 0.01282459]
# TRUE: [-0.01934508 -0.00652744 -0.01187656 -0.01401706 -0.01305397]
# PREDICTED: [0.01902134 0.00631552 0.01158399 0.01379863 0.01289862]
# TRUE: [-0.01849817 -0.00568424 -0.01108516 -0.01320484 -0.01226627]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:431 LOSS_wl:4.48719475798498e-07
# EPOCH:432 LOSS_wl:4.941683187098533e-07
# EPOCH:433 LOSS_wl:4.406501545872743e-07
# EPOCH:434 LOSS_wl:4.105481252736354e-07
# EPOCH:435 LOSS_wl:4.3526725335141236e-07
# EPOCH:436 LOSS_wl:4.2843103642553615e-07
# EPOCH:437 LOSS_wl:4.586589170685329e-07
# EPOCH:438 LOSS_wl:3.9992335132410517e-07
# EPOCH:439 LOSS_wl:4.414316379097727e-07
# EPOCH:440 LOSS_wl:4.0736594542067905e-07
# PREDICTED: [0.01913785 0.00619002 0.01168031 0.01377693 0.01283014]
# TRUE: [-0.01937734 -0.00651372 -0.01190876 -0.01402085 -0.01308929]
# PREDICTED: [0.01908953 0.00626045 0.01164091 0.0137431  0.01290747]
# TRUE: [-0.01842361 -0.00560851 -0.01098665 -0.0131055  -0.01218299]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:441 LOSS_wl:4.3531377968974994e-07
# EPOCH:442 LOSS_wl:4.330003946506622e-07
# LR_BR:3.242956679461172E-07
# LR_UP:2.788942744336608E-07
# EPOCH:443 LOSS_wl:4.443878651727573e-07
# EPOCH:444 LOSS_wl:4.520484537806624e-07
# EPOCH:445 LOSS_wl:4.007995926258445e-07
# EPOCH:446 LOSS_wl:4.7380441969835374e-07
# EPOCH:447 LOSS_wl:4.243256057634426e-07
# EPOCH:448 LOSS_wl:4.7219387511177047e-07
# EPOCH:449 LOSS_wl:4.4610325744542934e-07
# LR_BR:2.788942744336608E-07
# LR_UP:2.398490760129483E-07
# EPOCH:450 LOSS_wl:4.6990388113954396e-07
# PREDICTED: [0.01912865 0.00625645 0.0116901  0.01371165 0.0128391 ]
# TRUE: [-0.01914613 -0.00630886 -0.01170028 -0.01382383 -0.01289446]
# PREDICTED: [0.01911424 0.00634    0.01154185 0.01373733 0.0127394 ]
# TRUE: [-0.01827781 -0.00548446 -0.01088396 -0.01299271 -0.0120726 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:451 LOSS_wl:3.9685053820903704e-07
# EPOCH:452 LOSS_wl:5.233576416685537e-07
# EPOCH:453 LOSS_wl:4.6619300064776326e-07
# EPOCH:454 LOSS_wl:4.476670483199996e-07
# EPOCH:455 LOSS_wl:7.802452728356002e-07
# LR_BR:2.398490760129483E-07
# LR_UP:2.0627020537113552E-07
# EPOCH:456 LOSS_wl:4.497433394590189e-07
# EPOCH:457 LOSS_wl:4.095221015631978e-07
# EPOCH:458 LOSS_wl:4.080858673205512e-07
# LR_BR:2.0627020537113552E-07
# LR_UP:1.7739237661917655E-07
# EPOCH:459 LOSS_wl:4.220453604375507e-07
# EPOCH:460 LOSS_wl:4.686891372784885e-07
# PREDICTED: [0.01910118 0.00625574 0.01166074 0.01379007 0.01276272]
# TRUE: [-0.01934068 -0.00648091 -0.01187886 -0.01399966 -0.01306752]
# PREDICTED: [0.01906536 0.00629071 0.01166347 0.01377585 0.01288471]
# TRUE: [-0.01840362 -0.00562712 -0.0109991  -0.01310333 -0.01219253]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:461 LOSS_wl:4.4542898081090243e-07
# EPOCH:462 LOSS_wl:4.828541477763792e-07
# EPOCH:463 LOSS_wl:4.2361682517366717e-07
# EPOCH:464 LOSS_wl:4.875009267379937e-07
# EPOCH:465 LOSS_wl:4.6905049089218664e-07
# EPOCH:466 LOSS_wl:4.685941519255721e-07
# EPOCH:467 LOSS_wl:4.462799836346676e-07
# LR_BR:1.7739237661917655E-07
# LR_UP:1.5255744389249183E-07
# EPOCH:468 LOSS_wl:4.3122133774886606e-07
# EPOCH:469 LOSS_wl:4.5743215082438837e-07
# EPOCH:470 LOSS_wl:4.655326790725667e-07
# PREDICTED: [0.01906737 0.00631609 0.0115805  0.01379937 0.0128408 ]
# TRUE: [-0.0192008  -0.0063699  -0.01173632 -0.01385223 -0.01292224]
# PREDICTED: [0.0190758  0.00628695 0.01174162 0.01377593 0.01288756]
# TRUE: [-0.01863551 -0.0058503  -0.01121491 -0.01331856 -0.01241539]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:471 LOSS_wl:4.2743099015751795e-07
# EPOCH:472 LOSS_wl:4.520809966379602e-07
# EPOCH:473 LOSS_wl:4.69563076421764e-07
# EPOCH:474 LOSS_wl:3.877862866374926e-07
# EPOCH:475 LOSS_wl:1.2583162742885179e-06
# EPOCH:476 LOSS_wl:4.1576944909138547e-07
# EPOCH:477 LOSS_wl:4.787987109011738e-07
# EPOCH:478 LOSS_wl:4.3538102545426227e-07
# LR_BR:1.5255744389249183E-07
# LR_UP:1.3119940174754298E-07
# EPOCH:479 LOSS_wl:4.3668123339557496e-07
# EPOCH:480 LOSS_wl:3.5144714161106094e-07
# PREDICTED: [0.01902557 0.00624892 0.01162765 0.01381538 0.01284502]
# TRUE: [-0.01928883 -0.00643794 -0.0118163  -0.01394088 -0.01302105]
# PREDICTED: [0.01908999 0.00623267 0.01170544 0.01381026 0.01285621]
# TRUE: [-0.01810322 -0.00531546 -0.01067292 -0.01278904 -0.01186774]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:481 LOSS_wl:4.778554512085975e-07
# EPOCH:482 LOSS_wl:4.462515903469466e-07
# EPOCH:483 LOSS_wl:5.215180181039614e-07
# EPOCH:484 LOSS_wl:4.4863276116302586e-07
# EPOCH:485 LOSS_wl:4.231299328694149e-07
# EPOCH:486 LOSS_wl:4.85202861000289e-07
# EPOCH:487 LOSS_wl:4.321464643908257e-07
# EPOCH:488 LOSS_wl:4.3649640701914905e-07
# EPOCH:489 LOSS_wl:5.150298534317699e-07
# LR_BR:1.3119940174754298E-07
# LR_UP:1.1283148550288697E-07
# EPOCH:490 LOSS_wl:4.4590424863599765e-07
# PREDICTED: [0.01904979 0.00623091 0.01162853 0.01372352 0.01289772]
# TRUE: [-0.01929139 -0.00643811 -0.01182381 -0.01392571 -0.01300745]
# PREDICTED: [0.01909009 0.00621795 0.01174156 0.01379077 0.0128485 ]
# TRUE: [-0.01867842 -0.00590136 -0.01127635 -0.01338864 -0.01247217]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:491 LOSS_wl:4.388512024888769e-07
# EPOCH:492 LOSS_wl:4.946847980136226e-07
# LR_BR:1.1283148550288697E-07
# LR_UP:9.703507753248279E-08
# EPOCH:493 LOSS_wl:3.994028077158873e-07
# EPOCH:494 LOSS_wl:4.436141978203523e-07
# EPOCH:495 LOSS_wl:4.360991852081497e-07
# EPOCH:496 LOSS_wl:4.7092169097595615e-07
# EPOCH:497 LOSS_wl:4.3832974938595726e-07
# EPOCH:498 LOSS_wl:4.893453251497704e-07
# EPOCH:499 LOSS_wl:4.4892794903717004e-07
# EPOCH:500 LOSS_wl:4.167005442923255e-07
# PREDICTED: [0.01908432 0.00624459 0.01169676 0.01385694 0.012808  ]
# TRUE: [-0.01904876 -0.00620215 -0.01158843 -0.01370681 -0.01278503]
# PREDICTED: [0.01913834 0.00631269 0.01169484 0.01370926 0.01283447]
# TRUE: [-0.01844474 -0.0056781  -0.01105883 -0.01317435 -0.0122518 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:501 LOSS_wl:4.112851286208752e-07
# EPOCH:502 LOSS_wl:4.405961249176471e-07
# EPOCH:503 LOSS_wl:4.866548692916695e-07
# EPOCH:504 LOSS_wl:4.6008065623937e-07
# EPOCH:505 LOSS_wl:4.6958612642811204e-07
# EPOCH:506 LOSS_wl:4.4097373574913945e-07
# LR_BR:9.703507753248279E-08
# LR_UP:8.34501666779352E-08
# EPOCH:507 LOSS_wl:4.6541825327039987e-07
# EPOCH:508 LOSS_wl:4.241351803102589e-07
# EPOCH:509 LOSS_wl:3.695118380164786e-07
# EPOCH:510 LOSS_wl:4.480598647660372e-07
# PREDICTED: [0.01912032 0.00636449 0.01163026 0.01380887 0.01281254]
# TRUE: [-0.01920283 -0.00634795 -0.01175634 -0.01388862 -0.01293609]
# PREDICTED: [0.01912274 0.00614423 0.01160963 0.0137328  0.01284085]
# TRUE: [-0.01834031 -0.00557949 -0.01096108 -0.01306629 -0.01214268]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:511 LOSS_wl:4.6792519015070866e-07
# EPOCH:512 LOSS_wl:4.41173199305922e-07
# EPOCH:513 LOSS_wl:4.003488243142783e-07
# EPOCH:514 LOSS_wl:4.4027368062415917e-07
# EPOCH:515 LOSS_wl:4.675520699493063e-07
# EPOCH:516 LOSS_wl:4.1787788518377056e-07
# EPOCH:517 LOSS_wl:4.607807113643503e-07
# EPOCH:518 LOSS_wl:4.4507311258712434e-07
# EPOCH:519 LOSS_wl:4.150267045588407e-07
# EPOCH:520 LOSS_wl:3.8092366594355553e-07
# PREDICTED: [0.01905761 0.00630723 0.01168081 0.01370358 0.0128018 ]
# TRUE: [-0.0193167  -0.00648159 -0.01186096 -0.01395441 -0.01304408]
# PREDICTED: [0.01916725 0.00629704 0.0115342  0.01378194 0.01286883]
# TRUE: [-0.01844807 -0.00565783 -0.01101997 -0.01316901 -0.01220402]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:521 LOSS_wl:4.702177136550745e-07
# EPOCH:522 LOSS_wl:4.1623877677920973e-07
# EPOCH:523 LOSS_wl:4.339277381859574e-07
# EPOCH:524 LOSS_wl:4.649822074043186e-07
# LR_BR:8.34501666779352E-08
# LR_UP:7.176714334302427E-08
# EPOCH:525 LOSS_wl:3.7490841009457654e-07
# EPOCH:526 LOSS_wl:4.1306114439976227e-07
# EPOCH:527 LOSS_wl:4.426267992130306e-07
# EPOCH:528 LOSS_wl:5.180856987863081e-07
# EPOCH:529 LOSS_wl:4.3238730995653896e-07
# EPOCH:530 LOSS_wl:4.578199366278568e-07
# PREDICTED: [0.01907326 0.00626678 0.01175321 0.01376968 0.01278652]
# TRUE: [-0.01925929 -0.00637669 -0.01178244 -0.01387501 -0.01295989]
# PREDICTED: [0.0190442  0.00611974 0.01170541 0.01381644 0.01282637]
# TRUE: [-0.01827009 -0.0054808  -0.01086266 -0.01293342 -0.01205587]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:531 LOSS_wl:4.264486506144749e-07
# EPOCH:532 LOSS_wl:4.878480694969767e-07
# EPOCH:533 LOSS_wl:5.102049271954456e-07
# EPOCH:534 LOSS_wl:3.9959803643796477e-07
# EPOCH:535 LOSS_wl:4.778113407155615e-07
# EPOCH:536 LOSS_wl:4.3342063804630016e-07
# EPOCH:537 LOSS_wl:4.78406548154453e-07
# EPOCH:538 LOSS_wl:4.129049671064422e-07
# EPOCH:539 LOSS_wl:4.074635739925725e-07
# EPOCH:540 LOSS_wl:4.85397663396725e-07
# PREDICTED: [0.01911964 0.00628844 0.01162336 0.01370426 0.01285915]
# TRUE: [-0.01919994 -0.00633585 -0.01172722 -0.01383298 -0.01292009]
# PREDICTED: [0.01902424 0.006253   0.01164497 0.01376343 0.012831  ]
# TRUE: [-0.01866331 -0.00588842 -0.01126529 -0.01336877 -0.01246205]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:541 LOSS_wl:4.2579648606988485e-07
# EPOCH:542 LOSS_wl:4.287326476060116e-07
# EPOCH:543 LOSS_wl:5.213519216340501e-07
# LR_BR:7.176714334302427E-08
# LR_UP:6.171974327500087E-08
# EPOCH:544 LOSS_wl:4.6638078288196994e-07
# EPOCH:545 LOSS_wl:4.4249446773392265e-07
# EPOCH:546 LOSS_wl:4.130727404572099e-07
# LR_BR:6.171974327500087E-08
# LR_UP:5.307897921650075E-08
# EPOCH:547 LOSS_wl:4.725841620256688e-07
# EPOCH:548 LOSS_wl:4.42437766423609e-07
# EPOCH:549 LOSS_wl:4.831479145650519e-07
# EPOCH:550 LOSS_wl:3.969569775108539e-07
# PREDICTED: [0.01909981 0.00629919 0.01170109 0.01370186 0.01283652]
# TRUE: [-0.01935327 -0.00649703 -0.01188454 -0.01400431 -0.01307051]
# PREDICTED: [0.01913758 0.0062568  0.01161426 0.01381046 0.01284366]
# TRUE: [-0.01839932 -0.00560921 -0.01098567 -0.01308259 -0.01218444]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:551 LOSS_wl:4.690204207236093e-07
# EPOCH:552 LOSS_wl:3.602480660447327e-07
# EPOCH:553 LOSS_wl:4.661224863866664e-07
# EPOCH:554 LOSS_wl:4.6820693455629225e-07
# EPOCH:555 LOSS_wl:4.5448919649970776e-07
# EPOCH:556 LOSS_wl:4.189191145087534e-07
# EPOCH:557 LOSS_wl:4.397625730234722e-07
# EPOCH:558 LOSS_wl:5.036399102209543e-07
# EPOCH:559 LOSS_wl:3.942278965496371e-07
# EPOCH:560 LOSS_wl:4.877976493844471e-07
# PREDICTED: [0.01905642 0.00630914 0.01171678 0.0137587  0.01283896]
# TRUE: [-0.01919996 -0.00634261 -0.01174594 -0.01388132 -0.01290954]
# PREDICTED: [0.01918508 0.00625307 0.01166579 0.01382898 0.01290107]
# TRUE: [-0.01849805 -0.00570379 -0.01110093 -0.01322441 -0.01227417]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:561 LOSS_wl:4.745789397020417e-07
# EPOCH:562 LOSS_wl:4.469014527330728e-07
# EPOCH:563 LOSS_wl:4.7010991011120495e-07
# LR_BR:5.307897921650075E-08
# LR_UP:4.5647922126190645E-08
# EPOCH:564 LOSS_wl:4.721289599274314e-07
# EPOCH:565 LOSS_wl:4.6320096203089633e-07
# EPOCH:566 LOSS_wl:4.2692607848948683e-07
# EPOCH:567 LOSS_wl:4.967461109117721e-07
# EPOCH:568 LOSS_wl:4.4158741729916073e-07
# EPOCH:569 LOSS_wl:4.2886637174888165e-07
# EPOCH:570 LOSS_wl:3.8001843449819717e-07
# LR_BR:4.5647922126190645E-08
# LR_UP:3.925721302852396E-08
# ...
# EPOCH:814 LOSS_wl:4.6369697770387575e-07
# EPOCH:815 LOSS_wl:4.2039101799673517e-07
# EPOCH:816 LOSS_wl:4.844125669478672e-07
# EPOCH:817 LOSS_wl:4.1373399994881765e-07
# EPOCH:818 LOSS_wl:4.341971475696482e-07
# EPOCH:819 LOSS_wl:4.752273241592775e-07
# EPOCH:820 LOSS_wl:3.97159908516187e-07
# PREDICTED: [0.01901681 0.00626086 0.01163845 0.01375644 0.012799  ]
# TRUE: [-0.01894512 -0.00605433 -0.0114403  -0.01357557 -0.01265594]
# PREDICTED: [0.01908076 0.00629538 0.01171689 0.01374677 0.01286479]
# TRUE: [-0.0181692  -0.0053479  -0.01072295 -0.01284703 -0.01193775]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:821 LOSS_wl:4.528244232915313e-07
# EPOCH:822 LOSS_wl:4.735577761039167e-07
# EPOCH:823 LOSS_wl:4.4365916096467117e-07
# EPOCH:824 LOSS_wl:3.901171226061706e-07
# EPOCH:825 LOSS_wl:4.400060049647436e-07
# EPOCH:826 LOSS_wl:4.3953701833743253e-07
# EPOCH:827 LOSS_wl:4.3807025917885767e-07
# EPOCH:828 LOSS_wl:4.1838080733214156e-07
# LR_BR:3.514751982462473E-09
# LR_UP:3.0226867049177267E-09
# EPOCH:829 LOSS_wl:4.4364981022226857e-07
# EPOCH:830 LOSS_wl:4.0636822973283415e-07
# PREDICTED: [0.01917236 0.00627011 0.01166153 0.01376299 0.01277747]
# TRUE: [-0.01942996 -0.00658592 -0.0119744  -0.0140701  -0.01315897]
# PREDICTED: [0.01909405 0.00633905 0.01158524 0.01378889 0.01286511]
# TRUE: [-0.01847068 -0.00570777 -0.01106083 -0.01316921 -0.01228786]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:831 LOSS_wl:4.57493143812826e-07
# EPOCH:832 LOSS_wl:4.316577530971699e-07
# EPOCH:833 LOSS_wl:4.6085722260613693e-07
# EPOCH:834 LOSS_wl:4.0720178162700904e-07
# EPOCH:835 LOSS_wl:4.4620350081459037e-07
# EPOCH:836 LOSS_wl:4.43922630211091e-07
# EPOCH:837 LOSS_wl:4.333599008532474e-07
# EPOCH:838 LOSS_wl:4.914131750410888e-07
# LR_BR:3.0226867049177267E-09
# LR_UP:2.5995105662292448E-09
# EPOCH:839 LOSS_wl:3.964994732541527e-07
# EPOCH:840 LOSS_wl:4.0564009395893663e-07
# PREDICTED: [0.0191081  0.00621192 0.01169633 0.01373662 0.01285117]
# TRUE: [-0.01949225 -0.00662876 -0.01203726 -0.01417503 -0.01317986]
# PREDICTED: [0.01905836 0.00626057 0.01171221 0.01377583 0.01285635]
# TRUE: [-0.01830799 -0.00550951 -0.01089644 -0.01298347 -0.01208045]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:841 LOSS_wl:3.7667828678422666e-07
# EPOCH:842 LOSS_wl:4.192043263628875e-07
# EPOCH:843 LOSS_wl:3.638079988377285e-07
# EPOCH:844 LOSS_wl:4.4303243385002133e-07
# EPOCH:845 LOSS_wl:4.4756680495083856e-07
# EPOCH:846 LOSS_wl:4.898353722637694e-07
# EPOCH:847 LOSS_wl:4.368941119992087e-07
# EPOCH:848 LOSS_wl:4.571436136302509e-07
# EPOCH:849 LOSS_wl:4.156309216796217e-07
# EPOCH:850 LOSS_wl:3.8292770909720275e-07
# PREDICTED: [0.01912734 0.00625426 0.01166053 0.01377186 0.01281621]
# TRUE: [-0.01945268 -0.00659599 -0.01200515 -0.01413486 -0.01317071]
# PREDICTED: [0.01914083 0.00623695 0.01163084 0.01372685 0.01283326]
# TRUE: [-0.01854795 -0.00575513 -0.01113189 -0.01325755 -0.01231366]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:851 LOSS_wl:4.821851007363875e-07
# EPOCH:852 LOSS_wl:4.175776666670572e-07
# EPOCH:853 LOSS_wl:4.328421141508443e-07
# EPOCH:854 LOSS_wl:4.4518060349219013e-07
# LR_BR:2.5995105662292448E-09
# LR_UP:2.2355790869571505E-09
# EPOCH:855 LOSS_wl:4.607574339843268e-07
# EPOCH:856 LOSS_wl:4.6292612410070433e-07
# EPOCH:857 LOSS_wl:4.4207064320289646e-07
# EPOCH:858 LOSS_wl:4.985345185559709e-07
# EPOCH:859 LOSS_wl:4.2764682461893244e-07
# EPOCH:860 LOSS_wl:4.0134284517989727e-07
# PREDICTED: [0.01913469 0.00631345 0.01171524 0.01383584 0.01275113]
# TRUE: [-0.01943548 -0.00658195 -0.01199597 -0.0141081  -0.01316262]
# PREDICTED: [0.01905932 0.00633199 0.01178673 0.01371588 0.01289569]
# TRUE: [-0.01828352 -0.0054942  -0.01087616 -0.01298358 -0.01206905]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:861 LOSS_wl:4.3528731907827023e-07
# EPOCH:862 LOSS_wl:4.046670483148773e-07
# EPOCH:863 LOSS_wl:4.3215621303716034e-07
# EPOCH:864 LOSS_wl:4.029656963666639e-07
# LR_BR:2.2355790869571505E-09
# LR_UP:1.9225980147831495E-09
# EPOCH:865 LOSS_wl:3.958009813231911e-07
# EPOCH:866 LOSS_wl:5.257047632767353e-07
# EPOCH:867 LOSS_wl:4.630463195098855e-07
# EPOCH:868 LOSS_wl:5.320673039932444e-07
# EPOCH:869 LOSS_wl:4.162847631050681e-07
# EPOCH:870 LOSS_wl:4.922057996736839e-07
# PREDICTED: [0.01905844 0.00633528 0.01165339 0.01371483 0.01282014]
# TRUE: [-0.01927733 -0.00643141 -0.01180975 -0.01393178 -0.01299918]
# PREDICTED: [0.01912613 0.00628384 0.01163959 0.01369481 0.01287958]
# TRUE: [-0.01848842 -0.00569346 -0.01107061 -0.01318706 -0.01226792]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:871 LOSS_wl:4.0006119661484263e-07
# EPOCH:872 LOSS_wl:4.487000921926665e-07
# EPOCH:873 LOSS_wl:4.7222462740137416e-07
# EPOCH:874 LOSS_wl:4.405106608373899e-07
# EPOCH:875 LOSS_wl:4.846866090701951e-07
# EPOCH:876 LOSS_wl:4.856466375713353e-07
# EPOCH:877 LOSS_wl:5.001863314646471e-07
# EPOCH:878 LOSS_wl:4.7484599008384976e-07
# EPOCH:879 LOSS_wl:4.40091213249616e-07
# EPOCH:880 LOSS_wl:4.3615176537059597e-07
# PREDICTED: [0.01909003 0.00630196 0.01170685 0.01371475 0.01284098]
# TRUE: [-0.0191776  -0.00632226 -0.0117182  -0.01382477 -0.01290659]
# PREDICTED: [0.01901376 0.00627976 0.01162637 0.01373379 0.01290356]
# TRUE: [-0.0182976  -0.00546853 -0.01087445 -0.01297846 -0.01206843]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:881 LOSS_wl:4.3906774749302713e-07
# EPOCH:882 LOSS_wl:4.0451283211950795e-07
# EPOCH:883 LOSS_wl:4.372062392121734e-07
# EPOCH:884 LOSS_wl:4.4491795847534377e-07
# EPOCH:885 LOSS_wl:4.2925685761474597e-07
# EPOCH:886 LOSS_wl:4.068937187184929e-07
# EPOCH:887 LOSS_wl:5.136364507052349e-07
# EPOCH:888 LOSS_wl:4.538744065030187e-07
# EPOCH:889 LOSS_wl:4.4699862655761535e-07
# EPOCH:890 LOSS_wl:4.959503030477208e-07
# LR_BR:1.9225980147831495E-09
# LR_UP:1.6534342927135085E-09
# PREDICTED: [0.01916135 0.00632432 0.01169247 0.01373047 0.01287244]
# TRUE: [-0.0191483  -0.00630112 -0.01169371 -0.01382534 -0.01286677]
# PREDICTED: [0.01910719 0.00633311 0.01158968 0.01366623 0.01289284]
# TRUE: [-0.01816799 -0.00534771 -0.01076215 -0.01284921 -0.01193362]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:891 LOSS_wl:4.6189180125111307e-07
# EPOCH:892 LOSS_wl:4.369767339085229e-07
# EPOCH:893 LOSS_wl:4.3696780949176173e-07
# LR_BR:1.6534342927135085E-09
# LR_UP:1.4219534917336174E-09
# EPOCH:894 LOSS_wl:4.299921272377105e-07
# EPOCH:895 LOSS_wl:5.160517275726306e-07
# EPOCH:896 LOSS_wl:4.7328111918432114e-07
# EPOCH:897 LOSS_wl:4.172265732904634e-07
# EPOCH:898 LOSS_wl:3.643723403001786e-07
# EPOCH:899 LOSS_wl:4.0339116935683705e-07
# EPOCH:900 LOSS_wl:5.142849772710179e-07
# PREDICTED: [0.01912294 0.00621238 0.01163656 0.01377813 0.01290458]
# TRUE: [-0.0192169  -0.0063728  -0.01174516 -0.0138886  -0.01294715]
# PREDICTED: [0.01913795 0.00623583 0.01167176 0.01366861 0.01284877]
# TRUE: [-0.01845305 -0.00565043 -0.01104145 -0.01317771 -0.01223128]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:901 LOSS_wl:4.3830451090798306e-07
# EPOCH:902 LOSS_wl:4.142734155720973e-07
# EPOCH:903 LOSS_wl:4.226783971716941e-07
# LR_BR:1.4219534917336174E-09
# LR_UP:1.2228800028909109E-09
# EPOCH:904 LOSS_wl:4.8004784503064e-07
# EPOCH:905 LOSS_wl:4.4610382587961794e-07
# EPOCH:906 LOSS_wl:4.178857864189922e-07
# EPOCH:907 LOSS_wl:4.6874689019205107e-07
# EPOCH:908 LOSS_wl:4.26525190277971e-07
# EPOCH:909 LOSS_wl:4.744481714169524e-07
# EPOCH:910 LOSS_wl:4.241910858127085e-07
# PREDICTED: [0.01912317 0.0062567  0.01174723 0.01377037 0.01287182]
# TRUE: [-0.01948089 -0.00662792 -0.01199886 -0.01413978 -0.01317092]
# PREDICTED: [0.01909467 0.00621721 0.01167499 0.01375587 0.01291026]
# TRUE: [-0.01864876 -0.00585112 -0.01121878 -0.01336257 -0.01242556]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:911 LOSS_wl:4.4832967205366003e-07
# EPOCH:912 LOSS_wl:4.557505803859385e-07
# EPOCH:913 LOSS_wl:4.2258440657860774e-07
# EPOCH:914 LOSS_wl:3.861864001919457e-07
# EPOCH:915 LOSS_wl:4.3656766024469107e-07
# EPOCH:916 LOSS_wl:4.894641278951894e-07
# EPOCH:917 LOSS_wl:4.843280407840211e-07
# EPOCH:918 LOSS_wl:4.888195235253079e-07
# EPOCH:919 LOSS_wl:3.9169549381767865e-07
# LR_BR:1.2228800028909109E-09
# LR_UP:1.0516768024861834E-09
# EPOCH:920 LOSS_wl:4.327837928030931e-07
# PREDICTED: [0.01914061 0.00623926 0.01167471 0.01371081 0.01275538]
# TRUE: [-0.0191659  -0.00634881 -0.01172166 -0.01383557 -0.01291749]
# PREDICTED: [0.01906039 0.00625411 0.01160264 0.01375341 0.01284284]
# TRUE: [-0.01846754 -0.00567192 -0.01105731 -0.01314387 -0.01225389]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:921 LOSS_wl:3.8137198998811073e-07
# EPOCH:922 LOSS_wl:4.7652937951170316e-07
# EPOCH:923 LOSS_wl:5.096303539176006e-07
# EPOCH:924 LOSS_wl:4.548793981484778e-07
# EPOCH:925 LOSS_wl:4.77685773603298e-07
# EPOCH:926 LOSS_wl:4.846782530876226e-07
# EPOCH:927 LOSS_wl:4.443358818662091e-07
# EPOCH:928 LOSS_wl:4.887215254711919e-07
# EPOCH:929 LOSS_wl:4.163948403856921e-07
# EPOCH:930 LOSS_wl:4.7209880449372577e-07
# PREDICTED: [0.01914035 0.00625609 0.01169979 0.01378639 0.01293896]
# TRUE: [-0.01909659 -0.00625678 -0.01164396 -0.01374216 -0.01283862]
# PREDICTED: [0.01911133 0.00626461 0.01166548 0.01381294 0.01278012]
# TRUE: [-0.01847676 -0.00567589 -0.01107916 -0.01317488 -0.01224874]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:931 LOSS_wl:5.128948146193579e-07
# EPOCH:932 LOSS_wl:4.26423895305561e-07
# EPOCH:933 LOSS_wl:4.821589527637116e-07
# EPOCH:934 LOSS_wl:4.2536817090876866e-07
# EPOCH:935 LOSS_wl:4.5395998427011364e-07
# EPOCH:936 LOSS_wl:4.883123096988129e-07
# EPOCH:937 LOSS_wl:4.516329283887899e-07
# EPOCH:938 LOSS_wl:4.140497082971706e-07
# EPOCH:939 LOSS_wl:3.9124941508816846e-07
# EPOCH:940 LOSS_wl:4.322833149217331e-07
# PREDICTED: [0.01908566 0.00628896 0.01163841 0.01372309 0.01281819]
# TRUE: [-0.01933793 -0.00647428 -0.01187965 -0.01398818 -0.01306421]
# PREDICTED: [0.01909156 0.00625361 0.01171089 0.0137973  0.01290382]
# TRUE: [-0.0185069  -0.00573269 -0.01108221 -0.01319986 -0.0122915 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:941 LOSS_wl:4.0951886148832273e-07
# EPOCH:942 LOSS_wl:5.297838470141869e-07
# EPOCH:943 LOSS_wl:4.783351528203639e-07
# EPOCH:944 LOSS_wl:4.918115337204654e-07
# EPOCH:945 LOSS_wl:4.109973019694735e-07
# LR_BR:1.0516768024861834E-09
# LR_UP:9.044420501381177E-10
# EPOCH:946 LOSS_wl:4.948477112520777e-07
# EPOCH:947 LOSS_wl:5.06116862197814e-07
# EPOCH:948 LOSS_wl:4.435690925674862e-07
# EPOCH:949 LOSS_wl:4.833199795939436e-07
# EPOCH:950 LOSS_wl:4.749878428356169e-07
# PREDICTED: [0.0190971  0.00629248 0.01168934 0.01377317 0.01279628]
# TRUE: [-0.01897244 -0.00615179 -0.01153492 -0.01364348 -0.01273522]
# PREDICTED: [0.01920239 0.00629536 0.01159395 0.01373687 0.01281101]
# TRUE: [-0.01844843 -0.00566291 -0.01104437 -0.01318219 -0.01223759]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:951 LOSS_wl:4.275988487734139e-07
# EPOCH:952 LOSS_wl:4.194562279735692e-07
# EPOCH:953 LOSS_wl:4.7281608317462087e-07
# EPOCH:954 LOSS_wl:4.5422549987961247e-07
# EPOCH:955 LOSS_wl:4.457902775811817e-07
# EPOCH:956 LOSS_wl:4.4591772052626766e-07
# LR_BR:9.044420501381177E-10
# LR_UP:7.778201631187812E-10
# EPOCH:957 LOSS_wl:3.8822344095024164e-07
# EPOCH:958 LOSS_wl:4.555599559807888e-07
# EPOCH:959 LOSS_wl:4.0848311755325994e-07
# EPOCH:960 LOSS_wl:4.287617230147589e-07
# PREDICTED: [0.01911763 0.006232   0.01170316 0.01384514 0.01279504]
# TRUE: [-0.01911177 -0.00627204 -0.01166485 -0.01377215 -0.01284005]
# PREDICTED: [0.0190921  0.0063281  0.01162577 0.0138073  0.0128205 ]
# TRUE: [-0.01842809 -0.00563226 -0.01101873 -0.01314356 -0.0121934 ]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:961 LOSS_wl:4.2694514945651463e-07
# LR_BR:7.778201631187812E-10
# LR_UP:6.689253402821518E-10
# EPOCH:962 LOSS_wl:4.3951621364612947e-07
# EPOCH:963 LOSS_wl:4.345533852756489e-07
# EPOCH:964 LOSS_wl:4.965819471181021e-07
# EPOCH:965 LOSS_wl:4.2071368966389855e-07
# EPOCH:966 LOSS_wl:4.798848181053472e-07
# EPOCH:967 LOSS_wl:3.981380984896532e-07
# EPOCH:968 LOSS_wl:4.811953431271832e-07
# EPOCH:969 LOSS_wl:4.3389701431806316e-07
# EPOCH:970 LOSS_wl:4.5276365767676907e-07
# PREDICTED: [0.01914606 0.00622023 0.01172922 0.01380143 0.0127778 ]
# TRUE: [-0.01924037 -0.00635237 -0.01177248 -0.01390161 -0.01294177]
# PREDICTED: [0.01920073 0.0061809  0.01172603 0.01373111 0.01275869]
# TRUE: [-0.01866056 -0.0058745  -0.01125387 -0.01334523 -0.01245073]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:971 LOSS_wl:4.475355410704651e-07
# LR_BR:6.689253402821518E-10
# LR_UP:5.752757926426505E-10
# EPOCH:972 LOSS_wl:4.4812620103584777e-07
# EPOCH:973 LOSS_wl:4.3643098024404026e-07
# EPOCH:974 LOSS_wl:3.8526880530298513e-07
# EPOCH:975 LOSS_wl:5.164069989405107e-07
# EPOCH:976 LOSS_wl:4.806439619642333e-07
# EPOCH:977 LOSS_wl:4.1600657141316333e-07
# EPOCH:978 LOSS_wl:4.1992461774498224e-07
# LR_BR:5.752757926426505E-10
# LR_UP:4.947371816726795E-10
# EPOCH:979 LOSS_wl:4.046476078656269e-07
# EPOCH:980 LOSS_wl:4.0979756477099727e-07
# PREDICTED: [0.01913417 0.00628594 0.01160016 0.01368385 0.01282111]
# TRUE: [-0.01921854 -0.00639159 -0.01177013 -0.01385867 -0.01296956]
# PREDICTED: [0.01903734 0.00618462 0.01164491 0.01376929 0.01279813]
# TRUE: [-0.01832774 -0.00554082 -0.01091793 -0.01301667 -0.01211448]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:981 LOSS_wl:5.033169259149872e-07
# EPOCH:982 LOSS_wl:4.330264857799193e-07
# EPOCH:983 LOSS_wl:4.417973400450137e-07
# EPOCH:984 LOSS_wl:4.811303710994252e-07
# LR_BR:4.947371816726795E-10
# LR_UP:4.2547397623850435E-10
# EPOCH:985 LOSS_wl:4.31322035865378e-07
# EPOCH:986 LOSS_wl:4.4865575432595506e-07
# EPOCH:987 LOSS_wl:4.7673520953139814e-07
# EPOCH:988 LOSS_wl:4.228757575219788e-07
# EPOCH:989 LOSS_wl:4.925491907670221e-07
# EPOCH:990 LOSS_wl:4.389048910979909e-07
# PREDICTED: [0.01911587 0.00620211 0.0116487  0.01379886 0.01278431]
# TRUE: [-0.01910423 -0.00625326 -0.01165556 -0.01379631 -0.01282267]
# PREDICTED: [0.01901073 0.00627433 0.01167617 0.0138063  0.01285755]
# TRUE: [-0.0185724  -0.00575348 -0.01114999 -0.01325278 -0.01233671]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
# EPOCH:991 LOSS_wl:4.360238392564497e-07
# EPOCH:992 LOSS_wl:4.815067313757027e-07
# LR_BR:4.2547397623850435E-10
# LR_UP:3.6590761956511375E-10
# EPOCH:993 LOSS_wl:4.828083888241963e-07
# EPOCH:994 LOSS_wl:4.912328108730435e-07
# EPOCH:995 LOSS_wl:4.4185290448695014e-07
# EPOCH:996 LOSS_wl:4.284720489522442e-07
# EPOCH:997 LOSS_wl:4.156588033765729e-07
# EPOCH:998 LOSS_wl:4.0626298414281337e-07
# EPOCH:999 LOSS_wl:4.698845543771313e-07
# EPOCH:1000 LOSS_wl:4.3017135453737865e-07
# PREDICTED: [0.01910461 0.0062868  0.01164514 0.01377472 0.0128023 ]
# TRUE: [-0.01913732 -0.00629391 -0.01168066 -0.01381845 -0.01287109]
# PREDICTED: [0.01906994 0.00624968 0.01171278 0.01382708 0.01289947]
# TRUE: [-0.01829903 -0.00551037 -0.01087987 -0.01300026 -0.01207333]
# TRUE: [0.00108574 0.00113749 0.00113136 0.00112386 0.00113836]
# TRUE: [0.00183502 0.00183482 0.00183438 0.00183312 0.00183332]
