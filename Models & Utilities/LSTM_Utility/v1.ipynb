# %%
import argparse
import os
import random,numpy
os.environ['CUBLAS_WORKSPACE_CONFIG'] = ':4096:8'

# %%
import torch
import torch.nn as nn
import torch.nn.parallel
import torch.optim as optim
import torch.nn.functional as F
import torch.utils.data
import torchvision
import torchvision.datasets as dset
import torchvision.transforms as transforms
import torchvision.utils as vutils
import torchvision.transforms.functional as RF
from PIL import Image
import numpy as np
import random,cv2,pandas,os,numpy
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# %%
seed = 999
print("Random Seed: ", seed)
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
torch.use_deterministic_algorithms(True)

workers = 2
nz = 100
beta1 = 0.5
lr = 0.0001
ngpu=1
ngf,nc = 3,3
ndf = 64

device = torch.device("cuda:0" if (torch.cuda.is_available() and ngpu > 0) else "cpu")
# Out:
# Random Seed:  999

# %%
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight.data, gain=0.02)
        
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.rafire=nn.Sequential(

            nn.Linear(12416, 2024),
            nn.Dropout(p=0.35),
            nn.SiLU(),
            
            nn.Linear(2024, 1524),
            nn.Dropout(p=0.35),
            nn.SiLU(),
            
            nn.Linear(1524, 1124),
            nn.Dropout(p=0.30),
            nn.SiLU(),
            
            nn.Linear(1124, 924),
            nn.Dropout(p=0.30),
            nn.SiLU(),
            
            nn.Linear(924, 824),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(824, 724),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(724, 624),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(624, 524),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(524, 424),
            nn.Dropout(p=0.15),
            nn.SiLU(),
            
            nn.Linear(424, 324),
            nn.Dropout(p=0.1),
            nn.SiLU(),
            
            nn.Linear(324, 283),
            nn.SiLU()
        )

    def forward(self,x):
        return self.rafire(x)

# %%
def weights_init(m):
    if isinstance(m, nn.Linear):
        nn.init.xavier_normal_(m.weight.data, gain=0.02)
        
class Discriminator_z(nn.Module):
    def __init__(self):
        super().__init__()
        self.rafire=nn.Sequential(

            nn.Linear(283, 924),
            nn.Dropout(p=0.30),
            nn.SiLU(),
            
            nn.Linear(924, 824),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(824, 724),
            nn.Dropout(p=0.25),
            nn.SiLU(),
            
            nn.Linear(724, 624),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(624, 524),
            nn.Dropout(p=0.2),
            nn.SiLU(),
            
            nn.Linear(524, 424),
            nn.Dropout(p=0.15),
            nn.SiLU(),
            
            nn.Linear(424, 324),
            nn.Dropout(p=0.1),
            nn.SiLU(),
            
            nn.Linear(324, 283),
            nn.SiLU()
        )

    def forward(self,x):
        return self.rafire(x)

# %%
netD = Discriminator().to(device)
if (device.type == 'cuda') and (ngpu > 1):
    netD = nn.DataParallel(netD, list(range(ngpu)))
netD.apply(weights_init)

netD.load_state_dict(torch.load(f"/kaggle/input/radire-model/result_rf_wl/2.638780927100015e-07.pth",map_location=torch.device('cpu'),weights_only=False))

netZ = Discriminator_z().to(device)
if (device.type == 'cuda') and (ngpu > 1):
    netZ = nn.DataParallel(netZ, list(range(ngpu)))
netZ.apply(weights_init)
# Out:
# Discriminator_z(
#   (rafire): Sequential(
#     (0): Linear(in_features=283, out_features=924, bias=True)
#     (1): Dropout(p=0.3, inplace=False)
#     (2): SiLU()
#     (3): Linear(in_features=924, out_features=824, bias=True)
#     (4): Dropout(p=0.25, inplace=False)
#     (5): SiLU()
#     (6): Linear(in_features=824, out_features=724, bias=True)
#     (7): Dropout(p=0.25, inplace=False)
#     (8): SiLU()
#     (9): Linear(in_features=724, out_features=624, bias=True)
#     (10): Dropout(p=0.2, inplace=False)
#     (11): SiLU()
#     (12): Linear(in_features=624, out_features=524, bias=True)
#     (13): Dropout(p=0.2, inplace=False)
#     (14): SiLU()
#     (15): Linear(in_features=524, out_features=424, bias=True)
#     (16): Dropout(p=0.15, inplace=False)
#     (17): SiLU()
#     (18): Linear(in_features=424, out_features=324, bias=True)
#     (19): Dropout(p=0.1, inplace=False)
#     (20): SiLU()
#     (21): Linear(in_features=324, out_features=283, bias=True)
#     (22): SiLU()
#   )
# )

# %%
criterion,img_devil = nn.MSELoss(),0
fixed_noise = torch.randn(1, nz, 1, 1, device=device)

optimizerZ = optim.AdamW(netZ.parameters(), lr=lr,betas=(beta1, 0.999))
schedulerZ=torch.optim.lr_scheduler.ExponentialLR(optimizerZ, gamma=0.86)

# %%
train_data=numpy.load(f"/kaggle/input/rafire-ariel/train_data.npy",allow_pickle='TRUE').item()
train_label_=pandas.read_csv("/kaggle/input/ariel-data-challenge-2024/train_labels.csv")
train_data_,train_label=[],[]

batch_size=10
batch_d,batch_l=[],[]
for i in train_data.keys():
    if len(batch_d)==batch_size:
        train_data_.append(numpy.array(batch_d)),train_label.append(numpy.array(batch_l))
        batch_d,batch_l=[],[]
    batch_d.append(train_data[i].reshape(-1))
    batch_l.append(numpy.array(train_label_[train_label_['planet_id']==int(i)]).reshape(-1)[1::])
    
train_data,train_label=torch.from_numpy(numpy.array(train_data_)).to(device),numpy.array(train_label)
train_data.shape,train_label.shape
# Out:
# (torch.Size([67, 10, 12416]), (67, 10, 283))

# %%
train_data_z=numpy.load(f"/kaggle/input/rafire-ariel/train_data.npy",allow_pickle='TRUE').item()

train_label_,z_w_=pandas.read_csv("/kaggle/input/ariel-data-challenge-2024/train_labels.csv"),[]
high_rf,i,j_r,k=1000,0,0,0
if os.path.exists(f"/kaggle/working/result_rf_sigma")==False:
    os.mkdir(f"/kaggle/working/result_rf_sigma")

while(True):
    optimizerZ.zero_grad()
    for data in range(len(train_data)):
        output = abs(netD(train_data[data].float())).float()#-0.0015)
        rafire_Z = abs(netZ(output.float()))

        sigma=numpy.array([[numpy.std([q[0],q[1]]) for q in zip(n[0],n[1])] for n in zip(output.cpu().detach().numpy(), train_label[data])])
        #print(sigma[:20])
        errZ_real = criterion(rafire_Z.float(), torch.from_numpy(sigma).float().to(device))
        errZ_real.backward()
        optimizerZ.step()
    
    print(f"EPOCH:{i} LOSS_wl:{errZ_real.item()}")
    if len(z_w_)>=3:
        if len([True for i in range(1,4) if z_w_[len(z_w_)-i]<=z_w_[len(z_w_)-3] and z_w_[len(z_w_)-i]>=z_w_[len(z_w_)-4]])==3:
            z_w_,j_r=[],0
            print(f"lr_br:{optimizerZ.param_groups[0]['lr']}".upper())
            schedulerZ.step()
            print(f"lr_up:{optimizerZ.param_groups[0]['lr']}".upper())
    z_w_.append(errZ_real.item())
    
    if k==10:
        k=0
        if errZ_real.item()<high_rf:
            high_rf=errZ_real.item()
            torch.save(netZ.state_dict(),f'/kaggle/working/result_rf_sigma/{errZ_real.item()}.pth')
        for i_ in train_label_['planet_id'][:2]:
            real_cpu=torch.from_numpy(train_data_z[i_].reshape(-1)).to(device)
            output = abs(netD(real_cpu.float()))#-0.0015)
            rafire_Z = abs(netZ(output.float()))           
            print(f"PREDICTED: {rafire_Z[:5].cpu().detach().numpy()}")
            label=numpy.array(train_label_[train_label_['planet_id']==int(i_)]).reshape(-1)[1::]
            print(label.shape,output.shape)
            print(f"TRUE: {[numpy.std([q[0],q[1]]) for q in zip(output[:5].cpu().detach().numpy(),label[::5])]}")
            
    if i>=100:
        break
    i+=1
    j_r+=1
    k+=1
# Out:
# EPOCH:0 LOSS_wl:1.5623358194716275e-05
# EPOCH:1 LOSS_wl:8.523355063516647e-06
# EPOCH:2 LOSS_wl:6.8237550294725224e-06
# EPOCH:3 LOSS_wl:3.7200570659479126e-06
# LR_BR:0.0001
# LR_UP:8.6E-05
# EPOCH:4 LOSS_wl:2.5461492896283744e-06
# EPOCH:5 LOSS_wl:2.4997007130878046e-06
# EPOCH:6 LOSS_wl:2.976587211378501e-06
# LR_BR:8.6E-05
# LR_UP:7.396E-05
# EPOCH:7 LOSS_wl:1.894239630928496e-06
# EPOCH:8 LOSS_wl:2.0300344658608083e-06
# EPOCH:9 LOSS_wl:1.9350443380972138e-06
# EPOCH:10 LOSS_wl:2.1548019049077993e-06
# PREDICTED: [0.00313602 0.00060913 0.00237902 0.00090063 0.00242672]
# (283,) torch.Size([283])
# TRUE: [0.0007453973135611882, 0.00039972399281426184, 0.0004540232487284079, 0.0005951690030004201, 0.0006014021223581983]
# PREDICTED: [0.00277874 0.00034667 0.00249187 0.00109508 0.00250177]
# (283,) torch.Size([283])
# TRUE: [0.00019651494484959815, 9.8667055783365e-05, 7.650563953857069e-05, 2.301363575953996e-05, 9.721001018044321e-05]
# EPOCH:11 LOSS_wl:2.2043045646569226e-06
# EPOCH:12 LOSS_wl:2.0941947695973795e-06
# EPOCH:13 LOSS_wl:2.1585231024801033e-06
# EPOCH:14 LOSS_wl:1.951017338797101e-06
# EPOCH:15 LOSS_wl:1.8826187897502678e-06
# EPOCH:16 LOSS_wl:2.2214280761545524e-06
# EPOCH:17 LOSS_wl:2.3335996957030147e-06
# EPOCH:18 LOSS_wl:2.6109564714715816e-06
# EPOCH:19 LOSS_wl:2.913892330980161e-06
# EPOCH:20 LOSS_wl:2.9209295462351292e-06
# PREDICTED: [0.00455809 0.00055616 0.00355337 0.00107792 0.00378537]
# (283,) torch.Size([283])
# TRUE: [0.00013722317310246618, 7.982334318482466e-05, 9.406532512228343e-05, 0.00010051760974346422, 9.629440091702801e-05]
# PREDICTED: [0.00482313 0.00053127 0.00340261 0.00131079 0.00364537]
# (283,) torch.Size([283])
# TRUE: [0.0005608551119677099, 0.00042826827201476313, 0.0004536094854637688, 0.0005323788062787428, 0.0004767835921214822]
# EPOCH:21 LOSS_wl:2.923714419011958e-06
# EPOCH:22 LOSS_wl:3.0771207093494013e-06
# EPOCH:23 LOSS_wl:3.283301566625596e-06
# EPOCH:24 LOSS_wl:3.398230774109834e-06
# EPOCH:25 LOSS_wl:3.4846493690565694e-06
# EPOCH:26 LOSS_wl:3.176025529683102e-06
# EPOCH:27 LOSS_wl:2.654718400663114e-06
# EPOCH:28 LOSS_wl:2.345417669857852e-06
# EPOCH:29 LOSS_wl:1.9466638150333893e-06
# EPOCH:30 LOSS_wl:1.641150106479472e-06
# PREDICTED: [6.3199950e-06 6.6461437e-04 3.5445392e-03 1.3676897e-03 3.0616440e-03]
# (283,) torch.Size([283])
# TRUE: [0.00014630717707994373, 4.194706525565274e-05, 8.204846994201991e-05, 0.0001084769544006022, 8.963428035530907e-05]
# PREDICTED: [0.0006222  0.00052267 0.00329071 0.00188464 0.00275841]
# (283,) torch.Size([283])
# TRUE: [0.0005926973218321177, 0.0004992931434460542, 0.00050072026327771, 0.0005453556222027912, 0.0005248156225847009]
# EPOCH:31 LOSS_wl:1.4306028788269032e-06
# EPOCH:32 LOSS_wl:1.3003924550503143e-06
# EPOCH:33 LOSS_wl:1.1764507235056954e-06
# EPOCH:34 LOSS_wl:1.1614528148129466e-06
# EPOCH:35 LOSS_wl:1.0159494649997214e-06
# EPOCH:36 LOSS_wl:9.740392670209985e-07
# EPOCH:37 LOSS_wl:9.60306806518929e-07
# EPOCH:38 LOSS_wl:9.177482525046798e-07
# EPOCH:39 LOSS_wl:9.83488234851393e-07
# EPOCH:40 LOSS_wl:8.974843694886658e-07
# PREDICTED: [2.1986186e-04 6.4260431e-04 5.0600135e-04 1.9156770e-03 8.2293773e-05]
# (283,) torch.Size([283])
# TRUE: [0.00021585945289778502, 0.00013714368651532717, 0.00016479042709987017, 0.00011263205006724916, 0.00014741152472015184]
# PREDICTED: [0.00056212 0.00066392 0.00029288 0.00167312 0.00028849]
# (283,) torch.Size([283])
# TRUE: [0.00014741363439143922, 0.00019079015409057952, 0.00018708821856935377, 0.0001883984513233229, 0.00018379387572202118]
# EPOCH:41 LOSS_wl:9.294079177379899e-07
# EPOCH:42 LOSS_wl:7.901283538558346e-07
# EPOCH:43 LOSS_wl:7.994582915671344e-07
# EPOCH:44 LOSS_wl:6.225818083294143e-07
# EPOCH:45 LOSS_wl:5.656100938722375e-07
# EPOCH:46 LOSS_wl:4.587619173435087e-07
# EPOCH:47 LOSS_wl:4.20210994889203e-07
# EPOCH:48 LOSS_wl:5.300660745888308e-07
# EPOCH:49 LOSS_wl:4.194137090962613e-07
# EPOCH:50 LOSS_wl:5.437541972241888e-07
# PREDICTED: [0.00085799 0.00088108 0.00010968 0.00084586 0.00078512]
# (283,) torch.Size([283])
# TRUE: [1.0493696730481668e-05, 1.4262279364328457e-05, 0.00032284852817836556, 0.0002211911844740925, 0.00037482242396253806]
# PREDICTED: [7.3497568e-04 9.0034615e-04 6.8339068e-05 8.9306553e-04 7.0963189e-04]
# (283,) torch.Size([283])
# TRUE: [0.0006070482169035199, 0.0005210477328435145, 0.0005481065670545852, 0.0005615441331292316, 0.0005744562217572633]
# EPOCH:51 LOSS_wl:7.36174456505978e-07
# EPOCH:52 LOSS_wl:3.190337736214133e-07
# EPOCH:53 LOSS_wl:3.5510370821612014e-07
# EPOCH:54 LOSS_wl:4.2620050066943804e-07
# EPOCH:55 LOSS_wl:3.910376449312025e-07
# EPOCH:56 LOSS_wl:4.4971497459300735e-07
# EPOCH:57 LOSS_wl:4.945677574141882e-07
# EPOCH:58 LOSS_wl:5.19919751695852e-07
# EPOCH:59 LOSS_wl:5.760450676461915e-07
# EPOCH:60 LOSS_wl:9.590613672116888e-07
# PREDICTED: [5.6876361e-05 5.4878212e-04 2.1655331e-04 1.0287026e-03 3.6090429e-04]
# (283,) torch.Size([283])
# TRUE: [0.00020946574880006702, 5.4234469643842055e-05, 0.000178424174684988, 8.396669792017661e-05, 0.0001855291898191319]
# PREDICTED: [0.00029427 0.00059451 0.00042633 0.00077668 0.00011379]
# (283,) torch.Size([283])
# TRUE: [8.093746409385178e-05, 7.652684064153657e-06, 3.869958915229087e-05, 6.0013684665151e-05, 4.594960821998088e-05]
# EPOCH:61 LOSS_wl:5.746977649323526e-07
# EPOCH:62 LOSS_wl:4.5896530309619266e-07
# EPOCH:63 LOSS_wl:4.295704343348916e-07
# EPOCH:64 LOSS_wl:3.4687906236285926e-07
# EPOCH:65 LOSS_wl:3.5368429962545633e-07
# EPOCH:66 LOSS_wl:4.6595613412137027e-07
# EPOCH:67 LOSS_wl:3.249483597755898e-07
# EPOCH:68 LOSS_wl:2.7967442406406917e-07
# EPOCH:69 LOSS_wl:3.423454018047778e-07
# EPOCH:70 LOSS_wl:2.91580846578654e-07
# PREDICTED: [8.0206344e-05 2.8076170e-03 1.7763220e-04 8.9790777e-04 6.4120570e-04]
# (283,) torch.Size([283])
# TRUE: [6.339164467724951e-05, 5.6038266847889496e-05, 4.4646788176105944e-05, 5.360596033750795e-05, 3.741327736679178e-05]
# PREDICTED: [9.7246229e-05 2.8220252e-03 2.7590871e-04 1.0241922e-03 5.4519274e-04]
# (283,) torch.Size([283])
# TRUE: [0.0002532604822646203, 0.0003130544145167432, 0.00028000976429839487, 0.0002710212573992833, 0.0002803128877261582]
# EPOCH:71 LOSS_wl:2.822436613314494e-07
# EPOCH:72 LOSS_wl:2.64842498154394e-07
# LR_BR:7.396E-05
# LR_UP:6.36056E-05
# EPOCH:73 LOSS_wl:1.7522192763408384e-07
# EPOCH:74 LOSS_wl:1.5022139621123642e-07
# EPOCH:75 LOSS_wl:2.162186234500041e-07
# LR_BR:6.36056E-05
# LR_UP:5.4700816E-05
# EPOCH:76 LOSS_wl:1.4832259864761e-07
# EPOCH:77 LOSS_wl:2.3123307357764133e-07
# EPOCH:78 LOSS_wl:1.825497975005419e-07
# EPOCH:79 LOSS_wl:1.9285995733753225e-07
# EPOCH:80 LOSS_wl:1.5759950144911272e-07
# LR_BR:5.4700816E-05
# LR_UP:4.704270176E-05
# PREDICTED: [0.000231   0.00048487 0.00039164 0.00225976 0.00033945]
# (283,) torch.Size([283])
# TRUE: [0.000534229698654162, 0.0005852889680684995, 0.0005846736032776966, 0.0005862746395821986, 0.0005793903133071615]
# PREDICTED: [0.00060789 0.00054723 0.00064801 0.00253296 0.00010904]
# (283,) torch.Size([283])
# TRUE: [0.0004898968062606332, 0.0006598099781624415, 0.0006163087021041954, 0.0005981208088224009, 0.0005654005367701945]
# EPOCH:81 LOSS_wl:1.6943651814926852e-07
# EPOCH:82 LOSS_wl:2.3125899417664186e-07
# EPOCH:83 LOSS_wl:1.7103852201216796e-07
# EPOCH:84 LOSS_wl:2.2913586406048125e-07
# EPOCH:85 LOSS_wl:2.3601054977007152e-07
# LR_BR:4.704270176E-05
# LR_UP:4.04567235136E-05
# EPOCH:86 LOSS_wl:3.170233355831442e-07
# EPOCH:87 LOSS_wl:2.9084210950713896e-07
# EPOCH:88 LOSS_wl:2.1088851553940913e-07
# EPOCH:89 LOSS_wl:3.0630314995505614e-07
# EPOCH:90 LOSS_wl:2.9521444844249345e-07
# PREDICTED: [0.0001559  0.00063925 0.00058535 0.00063082 0.00090324]
# (283,) torch.Size([283])
# TRUE: [0.00036351605883603005, 3.564002145170085e-05, 0.00019808398906890896, 0.00026878613361151196, 0.0002667060348376288]
# PREDICTED: [0.00052413 0.00050067 0.00014945 0.00106383 0.00037726]
# (283,) torch.Size([283])
# TRUE: [0.00043085947718837585, 0.00028885044674804427, 0.00034331472828571553, 0.00036850453751411283, 0.00037998436843770774]
# EPOCH:91 LOSS_wl:2.3587971043070866e-07
# EPOCH:92 LOSS_wl:2.799055494051572e-07
# LR_BR:4.04567235136E-05
# LR_UP:3.4792782221696E-05
# EPOCH:93 LOSS_wl:3.2301383612320933e-07
# EPOCH:94 LOSS_wl:4.726274482891313e-07
# EPOCH:95 LOSS_wl:5.125244229020609e-07
# EPOCH:96 LOSS_wl:9.753284757607616e-07
# EPOCH:97 LOSS_wl:7.986704417817236e-07
# EPOCH:98 LOSS_wl:5.968966547698074e-07
# EPOCH:99 LOSS_wl:6.059952397663437e-07
# LR_BR:3.4792782221696E-05
# LR_UP:2.992179271065856E-05
# EPOCH:100 LOSS_wl:4.493908249969536e-07
# PREDICTED: [5.8952940e-04 5.2742142e-04 2.5682346e-05 5.6409300e-04 9.4896014e-04]
# (283,) torch.Size([283])
# TRUE: [0.001179205389756607, 0.0011087901602880549, 0.0011319608904682532, 0.0011633980096037802, 0.0011623183841056777]
# PREDICTED: [7.4621075e-04 5.5549259e-04 4.6663601e-05 6.6359545e-04 1.0571266e-03]
# (283,) torch.Size([283])
# TRUE: [0.0002831979046332958, 0.0002521666400641761, 0.0002698925743397033, 0.00028590600403275335, 0.0002850953455621305]
